# %%
# Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
 
## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
#Read in the csv file and convert to a Pandas dataframe
df_shows = pd.read_csv('tv_shows.csv')
df_movies = pd.read_csv('movies.csv')

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
df_shows.head()
# Out:
#                  Title  Years Content Rating Total Ratings  IMDb Rating
# 0   1. Game of Thrones  TV-MA      2011–2019        (2.4M)          9.2
# 1      2. Breaking Bad  TV-MA      2008–2013        (2.3M)          9.5
# 2   3. Stranger Things  TV-14      2016–2025        (1.4M)          8.7
# 3           4. Friends  TV-14      1994–2004        (1.1M)          8.9
# 4  5. The Walking Dead  TV-MA      2010–2022        (1.1M)          8.1

# %%
df_movies.head()
# Out:
#                                  Title   Year  Metascore Total Ratings  \
# 0                         1. The Gorge  PG-13       57.0         (76K)
# 1                     2. The Brutalist      R       90.0         (59K)
# 2                        3. The Monkey      R       61.0         (16K)
# 3  4. Captain America: Brave New World  PG-13       42.0         (65K)
# 4                         5. Nosferatu      R       78.0        (171K)
#
#    Rating Duration Parental Rating
# 0     6.8     2025           2h 7m
# 1     7.6     2024          3h 34m
# 2     6.4     2025          1h 38m
# 3     6.0     2025          1h 58m
# 4     7.3     2024          2h 12m

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
df_shows.describe()
# Out:
#        IMDb Rating
# count  6150.000000
# mean      7.302065
# std       1.036168
# min       1.000000
# 25%       6.800000
# 50%       7.400000
# 75%       8.000000
# max       9.900000

# %%
df_shows.describe(include='object')
# Out:
#                      Title  Years Content Rating Total Ratings
# count                 6150   4943           6150          6150
# unique                6150     21            830           349
# top     1. Game of Thrones  TV-14          2023–        (2.1K)
# freq                     1   1679            178           165

# %%
df_shows.shape
# Out:
# (6150, 5)

# %%
df_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6150 entries, 0 to 6149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           6150 non-null   object
#  1   Years           4943 non-null   object
#  2   Content Rating  6150 non-null   object
#  3   Total Ratings   6150 non-null   object
#  4   IMDb Rating     6150 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 240.4+ KB

# %%
df_movies.describe()
# Out:
#          Metascore       Rating
# count  5186.000000  5934.000000
# mean     59.642113     6.613397
# std      17.493516     0.977233
# min       1.000000     1.900000
# 25%      47.000000     6.100000
# 50%      60.000000     6.700000
# 75%      72.000000     7.300000
# max     100.000000     9.600000

# %%
df_movies.describe(include='object')
# Out:
#                Title  Year Total Ratings Duration Parental Rating
# count           6150  5628          5934     6096            5988
# unique          6150    21           955      105             163
# top     1. The Gorge     R         (13K)     2024          1h 40m
# freq               1  2549            56      489             166

# %%
df_movies.shape
# Out:
# (6150, 7)

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6150 entries, 0 to 6149
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            6150 non-null   object
#  1   Year             5628 non-null   object
#  2   Metascore        5186 non-null   float64
#  3   Total Ratings    5934 non-null   object
#  4   Rating           5934 non-null   float64
#  5   Duration         6096 non-null   object
#  6   Parental Rating  5988 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 336.5+ KB

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %%
# The data is scraped directly from the IMDb website, ensuring its authenticity and reliability.

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %%
# The dataset contains information on the most popular movies and TV shows up to the current year.

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %%
# Since the data is sourced from a single platform, it maintains consistency in formatting and criteria.

# %% [markdown]
# #### 4. Relevance:
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.
#
# **Key considerations for relevance include:**
#
# > 1. Sample Appropriateness: Confirm that your data sample aligns with your analysis objectives. For instance, utilizing data from the Northern region will not yield accurate insights for the Western region of the Kingdom.
# >
# > 2. Variable Selection: Any column will not be relevant for our analysis, we can get rid of these using the drop() method. We will set the “axis” argument to 1 since we’re dealing with columns, and set the “inplace” argument to True to make the change permanent.

# %%
# The scraped data is relevant as it aligns with our objective of analyzing movies and TV shows.

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
df_shows.duplicated().sum()
# Out:
# 0

# %%
df_movies.duplicated().sum()
# Out:
# 0

# %%
# go to delete duplicates columns

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %%
df_shows.isnull().sum()
# Out:
# Title                0
# Years             1207
# Content Rating       0
# Total Ratings        0
# IMDb Rating          0
# dtype: int64

# %%
df_movies.isnull().sum().sort_values(ascending=False)
# Out:
# Metascore          964
# Year               522
# Total Ratings      216
# Rating             216
# Parental Rating    162
# Duration            54
# Title                0
# dtype: int64

# %%
# go to clean them

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %%
# check columns types 
df_shows.dtypes
# Out:
# Title              object
# Years              object
# Content Rating     object
# Total Ratings      object
# IMDb Rating       float64
# dtype: object

# %%
df_movies.dtypes
# Out:
# Title               object
# Year                object
# Metascore          float64
# Total Ratings       object
# Rating             float64
# Duration            object
# Parental Rating     object
# dtype: object

# %%
# go to clean them

# %%
# check outliers

# %% [markdown]
# **What is an Outlier?**
# Outlier is an row/observation that appears far away and diverges from an overall pattern in a sample.
#
# **What are the types of Outliers?**
# 1. Univariate: These outliers can be found when we look at distribution of a single variable
# 2. Multivariate: are outliers in an n-dimensional space. In order to find them, you have to look at distributions in multi-dimensions. example (hight=100, weight=100) for a person
#
# **What causes Outliers?**
# Whenever we come across outliers, the ideal way to tackle them is to find out the reason of having these outliers. The method to deal with them would then depend on the reason of their occurrence.
#
# Let’s understand various types of outliers:
#
# 1. Data Entry Errors:- Human errors such as errors caused during data collection, recording, or entry can cause outliers in data.
# 2. Measurement Error: It is the most common source of outliers. This is caused when the measurement instrument used turns out to be faulty.
# 3. Data Processing Error: Whenever we perform data mining, we extract data from multiple sources. It is possible that some manipulation or extraction errors may lead to outliers in the dataset.
# 4. Sampling error: For instance, we have to measure the height of athletes. By mistake, we include a few basketball players in the sample. This inclusion is likely to cause outliers in the dataset.
# 5. Natural Outlier: When an outlier is not artificial (due to error), it is a natural outlier. For instance: In my last assignment with one of the renowned insurance company, I noticed that the performance of top 50 financial advisors was far higher than rest of the population. Surprisingly, it was not due to any error. Hence, whenever we perform any data mining activity with advisors, we used to treat this segment separately.
#
#
# **What is the impact of Outliers on a dataset?**
#
#
# ![image.png](https://www.analyticsvidhya.com/wp-content/uploads/2015/02/Outlier_31.png)
#
#
#
# **How to detect Outliers?**
#
# 1. Most commonly used method to detect outliers is visualization (Univariate Graphical Analysis).
#
# We use 3 common visualization methods:
# >- Box-plot: A box plot is a method for graphically depicting groups of numerical data through their quartiles. The box extends from the Q1 to Q3 quartile values of the data, with a line at the median (Q2). The whiskers extend from the edges of the box to show the range of the data. Outlier points are those past the end of the whiskers. Box plots show robust measures of location and spread as well as providing information about symmetry and outliers.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:698/format:webp/1*VK5iHA2AB28HSZwWwUbNYg.png)
# >
# >
# >- Histogram
# >- Scatter Plot: A scatter plot is a mathematical diagram using Cartesian coordinates to display values for two variables for a set of data. The data are displayed as a collection of points, each having the value of one variable determining the position on the horizontal axis and the value of the other variable determining the position on the vertical axis. The points that are far from the population can be termed as an outlier.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:4800/format:webp/1*Ov6aH-8yIwNoUxtMFwgx4g.png)
# >
# >
#
# 2. Using statistical method (Univariate Non-Graphical analysis):
# >- Any value, which is beyond the range of -1.5 x IQR to 1.5 x IQR
#
# ![image.png](https://www.whatissixsigma.net/wp-content/uploads/2015/07/Box-Plot-Diagram-to-identify-Outliers-figure-1.png)
#
# >- Use capping methods. Any value which out of range of 5th and 95th percentile can be considered as outlier
# >- Data points, three or more standard deviation away from mean are considered outlier: The Z-score is the signed number of standard deviations by which the value of an observation or data point is above the mean value of what is being observed or measured. While calculating the Z-score we re-scale and center the data and look for data points that are too far from zero. These data points which are way too far from zero will be treated as the outliers. In most of the cases, a threshold of 3 or -3 is used i.e if the Z-score value is greater than or less than 3 or -3 respectively, that data point will be identified as outliers.
# > - Outlier detection is merely a special case of the examination of data for influential data points and it also depends on the business understanding

# %%
# go to univariate graphical analysis
# go to lesson : data visualisation 1 - chart type section
# then go to univariate graphical analysis
# detect outliers using graphs varbaly

# %%
# go to lesson: statistics 1 then statistics 3
# then go to univariate Non graphical analysis
# detect outliers using numerical statistics

# %%
# go to delete ouliers

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# -------------------

# %% [markdown]
# ### Handling missing values:

# %% [markdown]
# **Why my data has missing values?**
# They may occur at two stages:
# 1. Data Extraction: It is possible that there are problems with extraction process. Errors at data extraction stage are typically easy to find and can be corrected easily as well.
# 2. Data collection: These errors occur at time of data collection and are harder to correct.
#
# **Why do we need to handle the missing data?**
# To avoid:
# - Bias the conclusions.
# - Leading the business to make wrong decisions.
#
# **Which are the methods to treat missing values ?**
# 1. Deletion: we delete rows where any of the variable is missing. Simplicity is one of the major advantage of this method, but this method reduces the power of model because it reduces the sample size.
#
# 2. Imputation: is a method to fill in the missing values with estimated ones. This imputation is one of the most frequently used methods.
#
#     2.1. Mean/ Mode/ Median Imputation: It consists of replacing the missing data for a given attribute by the mean or median (quantitative attribute) or mode (qualitative attribute) of all known values of that variable.
#     > It can be of two types:
#     > - Generalized Imputation: In this case, we calculate the mean or median for all non missing values of that variable then replace missing value with mean or median.
#     > - Similar case Imputation: In this case, we calculate average for each group individually of non missing values then replace the missing value based on the group.
#
#     2.2. Constant Value
#
#     2.3. Forward Filling
#
#     2.4. Backward Filling
#
# 6. Prediction Model:  Prediction model is one of the sophisticated method for handling missing data. Here, we create a predictive model to estimate values that will substitute the missing data.  In this case, we divide our data set into two sets: One set with no missing values for the variable and another one with missing values. First data set become training data set of the model while second data set with missing values is test data set and variable with missing values is treated as target variable. Next, we create a model to predict target variable based on other attributes of the training data set and populate missing values of test data set.
#
# > There are 2 drawbacks for this approach:
# > - The model estimated values are usually more well-behaved than the true values
# > - If there are no relationships with attributes in the data set and the attribute with missing values, then the model will not be precise for estimating missing values.
#
# 9. KNN Imputation: In this method of imputation, the missing values of an attribute are imputed using the given number of attributes that are most similar to the attribute whose values are missing. The similarity of two attributes is determined using a distance function. It is also known to have certain advantage & disadvantages.
#
#    > **Advantages:**
#    > - k-nearest neighbour can predict both qualitative & quantitative attributes
#    > - Creation of predictive model for each attribute with missing data is not required
#    > - Attributes with multiple missing values can be easily treated
#    > - Correlation structure of the data is taken into consideration
#
#    > **Disadvantage:**
#    > - KNN algorithm is very time-consuming in analyzing large database. It searches through all the dataset looking for the most similar instances.
#    > - Choice of k-value is very critical. Higher value of k would include attributes which are significantly different from what we need whereas lower value of k implies missing out of significant attributes.
#
# --------------------

# %% [markdown]
# ### df_shows

# %%
def split_title_and_rank(df, title_col='Title'):
    """
    Splits the specified title column into two new columns: 'Rank' and 'Movie'.
    
    Assumes that each title entry is in the format: "rank. MovieName"
    
    Parameters:
        df (pd.DataFrame): DataFrame containing the title column.
        title_col (str): Name of the column to split (default 'Title').
    
    Returns:
        pd.DataFrame: DataFrame with new 'Rank' and 'Movie' columns.
    """
    # Split the column into two parts using the first occurrence of '.'
    df[['Rank', 'Movie']] = df[title_col].str.split('.', n=1, expand=True)
    
    # Remove extra whitespace from the new columns
    df['Rank'] = df['Rank'].str.strip()
    df['Movie'] = df['Movie'].str.strip()
    
    return df


shows = split_title_and_rank(df_shows)

shows.head()
# Out:
#                  Title  Years Content Rating Total Ratings  IMDb Rating Rank  \
# 0   1. Game of Thrones  TV-MA      2011–2019        (2.4M)          9.2    1
# 1      2. Breaking Bad  TV-MA      2008–2013        (2.3M)          9.5    2
# 2   3. Stranger Things  TV-14      2016–2025        (1.4M)          8.7    3
# 3           4. Friends  TV-14      1994–2004        (1.1M)          8.9    4
# 4  5. The Walking Dead  TV-MA      2010–2022        (1.1M)          8.1    5
#
#               Movie
# 0   Game of Thrones
# 1      Breaking Bad
# 2   Stranger Things
# 3           Friends
# 4  The Walking Dead

# %%
df_shows.rename(columns={'Years': 'Content Rating', 'Content Rating': 'Years'}, inplace=True)
df_shows.drop('Title', axis=1, inplace=True)

# %%
df_shows.rename(columns={'Movie': 'Series'}, inplace=True)

# %%
ordered_columns = ['Rank', 'Series', 'Years', 'Content Rating', 'IMDb Rating', 'Total Ratings']
df_shows = df_shows[ordered_columns].copy()
df_shows
# Out:
#       Rank                            Series      Years Content Rating  \
# 0        1                   Game of Thrones  2011–2019          TV-MA
# 1        2                      Breaking Bad  2008–2013          TV-MA
# 2        3                   Stranger Things  2016–2025          TV-14
# 3        4                           Friends  1994–2004          TV-14
# 4        5                  The Walking Dead  2010–2022          TV-MA
# ...    ...                               ...        ...            ...
# 6145  6146                        Spider-Man  1981–1982          TV-Y7
# 6146  6147                  Complete Savages  2004–2005          TV-PG
# 6147  6148  A Shot at Love with Tila Tequila  2007–2008            NaN
# 6148  6149                             Ariza  2020–2021            NaN
# 6149  6150                            Tanked  2011–2018            NaN
#
#       IMDb Rating Total Ratings
# 0             9.2        (2.4M)
# 1             9.5        (2.3M)
# 2             8.7        (1.4M)
# 3             8.9        (1.1M)
# 4             8.1        (1.1M)
# ...           ...           ...
# 6145          6.8        (2.1K)
# 6146          7.3        (2.1K)
# 6147          3.1        (2.1K)
# 6148          6.3        (2.1K)
# 6149          6.5          (2K)
#
# [6150 rows x 6 columns]

# %%
df_shows.duplicated().sum()
# Out:
# 0

# %%
df_shows.isnull().sum().sort_values(ascending=False)
# Out:
# Content Rating    1207
# Rank                 0
# Series               0
# Years                0
# IMDb Rating          0
# Total Ratings        0
# dtype: int64

# %%
# Standardize text to avoid issues
df_shows["Years"] = df_shows["Years"].astype(str).fillna("")  # Ensure all values are strings
df_shows["Years"] = df_shows["Years"].str.replace("–", "-")  # Replace en dash with hyphen
df_shows["Years"] = df_shows["Years"].str.replace("—", "-")  # Replace em dash with hyphen

def parse_years(year_str, artificial_end=2025):
    """
    Converts "Years" column into (start_year, end_year, ongoing).
    """
    year_str = year_str.strip()
    
    if "-" in year_str:
        start_part, end_part = year_str.split("-", maxsplit=1)
        start_part = start_part.strip()
        end_part = end_part.strip()

        start_year = int(start_part) if start_part.isdigit() else None
        end_year = int(end_part) if end_part.isdigit() else artificial_end if end_part == "" else None
        ongoing = end_part == ""
    
    else:
        start_year = int(year_str) if year_str.isdigit() else None
        end_year = start_year
        ongoing = False

    return start_year, end_year, ongoing

def compute_run_length(start, end):
    return max(0, end - start) if start and end else None

# Create new columns
df_shows["start_year"] = None
df_shows["end_year"] = None
df_shows["ongoing"] = False
df_shows["run_length"] = None

# Process each row
for i, row in df_shows.iterrows():
    yrs = row["Years"]
    print(f"Row {i} | Raw '{yrs}'")  # Debugging line
    
    s, e, og = parse_years(yrs, artificial_end=2025)
    print(f"Row {i} | Parsed: start={s}, end={e}, ongoing={og}")  # Debugging line
    
    df_shows.at[i, "start_year"] = s
    df_shows.at[i, "end_year"] = e
    df_shows.at[i, "ongoing"] = og
    df_shows.at[i, "run_length"] = compute_run_length(s, e)

print("\n✅ Processed DataFrame:")
# Out:
# Row 0 | Raw '2011-2019'
# Row 0 | Parsed: start=2011, end=2019, ongoing=False
# Row 1 | Raw '2008-2013'
# Row 1 | Parsed: start=2008, end=2013, ongoing=False
# Row 2 | Raw '2016-2025'
# Row 2 | Parsed: start=2016, end=2025, ongoing=False
# Row 3 | Raw '1994-2004'
# Row 3 | Parsed: start=1994, end=2004, ongoing=False
# Row 4 | Raw '2010-2022'
# Row 4 | Parsed: start=2010, end=2022, ongoing=False
# Row 5 | Raw '2010-2017'
# Row 5 | Parsed: start=2010, end=2017, ongoing=False
# Row 6 | Raw '2007-2019'
# Row 6 | Parsed: start=2007, end=2019, ongoing=False
# Row 7 | Raw '2006-2013'
# Row 7 | Parsed: start=2006, end=2013, ongoing=False
# Row 8 | Raw '2005-2013'
# Row 8 | Parsed: start=2005, end=2013, ongoing=False
# Row 9 | Raw '2019-'
# Row 9 | Parsed: start=2019, end=2025, ongoing=True
# Row 10 | Raw '2005-2014'
# Row 10 | Parsed: start=2005, end=2014, ongoing=False
# Row 11 | Raw '2015-2022'
# Row 11 | Parsed: start=2015, end=2022, ongoing=False
# Row 12 | Raw '2013-2022'
# Row 12 | Parsed: start=2013, end=2022, ongoing=False
# Row 13 | Raw '2014-'
# Row 13 | Parsed: start=2014, end=2025, ongoing=True
# Row 14 | Raw '2011-'
# Row 14 | Parsed: start=2011, end=2025, ongoing=True
# Row 15 | Raw '2021-2025'
# Row 15 | Parsed: start=2021, end=2025, ongoing=False
# Row 16 | Raw '2013-'
# Row 16 | Parsed: start=2013, end=2025, ongoing=True
# Row 17 | Raw '2004-2010'
# Row 17 | Parsed: start=2004, end=2010, ongoing=False
# Row 18 | Raw '2005-2017'
# Row 18 | Parsed: start=2005, end=2017, ongoing=False
# Row 19 | Raw '2019-'
# Row 19 | Parsed: start=2019, end=2025, ongoing=True
# Row 20 | Raw '2013-2020'
# Row 20 | Parsed: start=2013, end=2020, ongoing=False
# Row 21 | Raw '2023-'
# Row 21 | Parsed: start=2023, end=2025, ongoing=True
# Row 22 | Raw '2019-'
# Row 22 | Parsed: start=2019, end=2025, ongoing=True
# Row 23 | Raw '2013-2023'
# Row 23 | Parsed: start=2013, end=2023, ongoing=False
# Row 24 | Raw '2017-2021'
# Row 24 | Parsed: start=2017, end=2021, ongoing=False
# Row 25 | Raw '2004-2012'
# Row 25 | Parsed: start=2004, end=2012, ongoing=False
# Row 26 | Raw '2016-2022'
# Row 26 | Parsed: start=2016, end=2022, ongoing=False
# Row 27 | Raw '2013-2018'
# Row 27 | Parsed: start=2013, end=2018, ongoing=False
# Row 28 | Raw '1999-2007'
# Row 28 | Parsed: start=1999, end=2007, ongoing=False
# Row 29 | Raw '2009-2020'
# Row 29 | Parsed: start=2009, end=2020, ongoing=False
# Row 30 | Raw '2011-2019'
# Row 30 | Parsed: start=2011, end=2019, ongoing=False
# Row 31 | Raw '2005-2020'
# Row 31 | Parsed: start=2005, end=2020, ongoing=False
# Row 32 | Raw '2015-2017'
# Row 32 | Parsed: start=2015, end=2017, ongoing=False
# Row 33 | Raw '2015-2018'
# Row 33 | Parsed: start=2015, end=2018, ongoing=False
# Row 34 | Raw '2017-2020'
# Row 34 | Parsed: start=2017, end=2020, ongoing=False
# Row 35 | Raw '2022-'
# Row 35 | Parsed: start=2022, end=2025, ongoing=True
# Row 36 | Raw '2012-2020'
# Row 36 | Parsed: start=2012, end=2020, ongoing=False
# Row 37 | Raw '1989-'
# Row 37 | Parsed: start=1989, end=2025, ongoing=True
# Row 38 | Raw '2014-2024'
# Row 38 | Parsed: start=2014, end=2024, ongoing=False
# Row 39 | Raw '2021-2023'
# Row 39 | Parsed: start=2021, end=2023, ongoing=False
# Row 40 | Raw '2015-2019'
# Row 40 | Parsed: start=2015, end=2019, ongoing=False
# Row 41 | Raw '2022-'
# Row 41 | Parsed: start=2022, end=2025, ongoing=True
# Row 42 | Raw '1997-'
# Row 42 | Parsed: start=1997, end=2025, ongoing=True
# Row 43 | Raw '2006-2007'
# Row 43 | Parsed: start=2006, end=2007, ongoing=False
# Row 44 | Raw '2022-'
# Row 44 | Parsed: start=2022, end=2025, ongoing=True
# Row 45 | Raw '2005-2008'
# Row 45 | Parsed: start=2005, end=2008, ongoing=False
# Row 46 | Raw '2002-2008'
# Row 46 | Parsed: start=2002, end=2008, ongoing=False
# Row 47 | Raw '2020-'
# Row 47 | Parsed: start=2020, end=2025, ongoing=True
# Row 48 | Raw '2013-2021'
# Row 48 | Parsed: start=2013, end=2021, ongoing=False
# Row 49 | Raw '2021-2024'
# Row 49 | Parsed: start=2021, end=2024, ongoing=False
# Row 50 | Raw '2014-2023'
# Row 50 | Parsed: start=2014, end=2023, ongoing=False
# Row 51 | Raw '1999-'
# Row 51 | Parsed: start=1999, end=2025, ongoing=True
# Row 52 | Raw '2019-2023'
# Row 52 | Parsed: start=2019, end=2023, ongoing=False
# Row 53 | Raw '2016-2021'
# Row 53 | Parsed: start=2016, end=2021, ongoing=False
# Row 54 | Raw '2011-2020'
# Row 54 | Parsed: start=2011, end=2020, ongoing=False
# Row 55 | Raw '2017-2022'
# Row 55 | Parsed: start=2017, end=2022, ongoing=False
# Row 56 | Raw '1989-1998'
# Row 56 | Parsed: start=1989, end=1998, ongoing=False
# Row 57 | Raw '2009-2017'
# Row 57 | Parsed: start=2009, end=2017, ongoing=False
# Row 58 | Raw '2017-2019'
# Row 58 | Parsed: start=2017, end=2019, ongoing=False
# Row 59 | Raw '2005-'
# Row 59 | Parsed: start=2005, end=2025, ongoing=True
# Row 60 | Raw '2011-'
# Row 60 | Parsed: start=2011, end=2025, ongoing=True
# Row 61 | Raw '2008-2014'
# Row 61 | Parsed: start=2008, end=2014, ongoing=False
# Row 62 | Raw '2003-2019'
# Row 62 | Parsed: start=2003, end=2019, ongoing=False
# Row 63 | Raw '2013-2019'
# Row 63 | Parsed: start=2013, end=2019, ongoing=False
# Row 64 | Raw '2017-2020'
# Row 64 | Parsed: start=2017, end=2020, ongoing=False
# Row 65 | Raw '2018-2025'
# Row 65 | Parsed: start=2018, end=2025, ongoing=False
# Row 66 | Raw '2021-'
# Row 66 | Parsed: start=2021, end=2025, ongoing=True
# Row 67 | Raw '2018-2023'
# Row 67 | Parsed: start=2018, end=2023, ongoing=False
# Row 68 | Raw '2011-2021'
# Row 68 | Parsed: start=2011, end=2021, ongoing=False
# Row 69 | Raw '2009-2015'
# Row 69 | Parsed: start=2009, end=2015, ongoing=False
# Row 70 | Raw '2019-2024'
# Row 70 | Parsed: start=2019, end=2024, ongoing=False
# Row 71 | Raw '2009-2015'
# Row 71 | Parsed: start=2009, end=2015, ongoing=False
# Row 72 | Raw '2024-'
# Row 72 | Parsed: start=2024, end=2025, ongoing=True
# Row 73 | Raw '2002-2003'
# Row 73 | Parsed: start=2002, end=2003, ongoing=False
# Row 74 | Raw '2013-2015'
# Row 74 | Parsed: start=2013, end=2015, ongoing=False
# Row 75 | Raw '2014-2020'
# Row 75 | Parsed: start=2014, end=2020, ongoing=False
# Row 76 | Raw '2003-2015'
# Row 76 | Parsed: start=2003, end=2015, ongoing=False
# Row 77 | Raw '2013-2023'
# Row 77 | Parsed: start=2013, end=2023, ongoing=False
# Row 78 | Raw '1999-'
# Row 78 | Parsed: start=1999, end=2025, ongoing=True
# Row 79 | Raw '2017-2019'
# Row 79 | Parsed: start=2017, end=2019, ongoing=False
# Row 80 | Raw '2001-2010'
# Row 80 | Parsed: start=2001, end=2010, ongoing=False
# Row 81 | Raw '2022-'
# Row 81 | Parsed: start=2022, end=2025, ongoing=True
# Row 82 | Raw '2007-2015'
# Row 82 | Parsed: start=2007, end=2015, ongoing=False
# Row 83 | Raw '2017-2025'
# Row 83 | Parsed: start=2017, end=2025, ongoing=False
# Row 84 | Raw '1999-'
# Row 84 | Parsed: start=1999, end=2025, ongoing=True
# Row 85 | Raw '2016-2023'
# Row 85 | Parsed: start=2016, end=2023, ongoing=False
# Row 86 | Raw '2019-'
# Row 86 | Parsed: start=2019, end=2025, ongoing=True
# Row 87 | Raw '2008-2014'
# Row 87 | Parsed: start=2008, end=2014, ongoing=False
# Row 88 | Raw '2010-2013'
# Row 88 | Parsed: start=2010, end=2013, ongoing=False
# Row 89 | Raw '2022-'
# Row 89 | Parsed: start=2022, end=2025, ongoing=True
# Row 90 | Raw '2018-2024'
# Row 90 | Parsed: start=2018, end=2024, ongoing=False
# Row 91 | Raw '2005-'
# Row 91 | Parsed: start=2005, end=2025, ongoing=True
# Row 92 | Raw '2008-2013'
# Row 92 | Parsed: start=2008, end=2013, ongoing=False
# Row 93 | Raw '1993-2018'
# Row 93 | Parsed: start=1993, end=2018, ongoing=False
# Row 94 | Raw '2006-2010'
# Row 94 | Parsed: start=2006, end=2010, ongoing=False
# Row 95 | Raw '2005-2022'
# Row 95 | Parsed: start=2005, end=2022, ongoing=False
# Row 96 | Raw '2011-2018'
# Row 96 | Parsed: start=2011, end=2018, ongoing=False
# Row 97 | Raw '2014-2019'
# Row 97 | Parsed: start=2014, end=2019, ongoing=False
# Row 98 | Raw '2022-'
# Row 98 | Parsed: start=2022, end=2025, ongoing=True
# Row 99 | Raw '2021-'
# Row 99 | Parsed: start=2021, end=2025, ongoing=True
# Row 100 | Raw '2011-2018'
# Row 100 | Parsed: start=2011, end=2018, ongoing=False
# Row 101 | Raw '2021-'
# Row 101 | Parsed: start=2021, end=2025, ongoing=True
# Row 102 | Raw '2017-2026'
# Row 102 | Parsed: start=2017, end=2026, ongoing=False
# Row 103 | Raw '2010-2015'
# Row 103 | Parsed: start=2010, end=2015, ongoing=False
# Row 104 | Raw '2017-2019'
# Row 104 | Parsed: start=2017, end=2019, ongoing=False
# Row 105 | Raw '2015-2019'
# Row 105 | Parsed: start=2015, end=2019, ongoing=False
# Row 106 | Raw '2013-2020'
# Row 106 | Parsed: start=2013, end=2020, ongoing=False
# Row 107 | Raw '1990-1991'
# Row 107 | Parsed: start=1990, end=1991, ongoing=False
# Row 108 | Raw '2005-'
# Row 108 | Parsed: start=2005, end=2025, ongoing=True
# Row 109 | Raw '2018-2025'
# Row 109 | Parsed: start=2018, end=2025, ongoing=False
# Row 110 | Raw '2016-2019'
# Row 110 | Parsed: start=2016, end=2019, ongoing=False
# Row 111 | Raw '2009-2010'
# Row 111 | Parsed: start=2009, end=2010, ongoing=False
# Row 112 | Raw '2019-'
# Row 112 | Parsed: start=2019, end=2025, ongoing=True
# Row 113 | Raw '2008-2015'
# Row 113 | Parsed: start=2008, end=2015, ongoing=False
# Row 114 | Raw '2010-2014'
# Row 114 | Parsed: start=2010, end=2014, ongoing=False
# Row 115 | Raw '2024-2026'
# Row 115 | Parsed: start=2024, end=2026, ongoing=False
# Row 116 | Raw '2014-2020'
# Row 116 | Parsed: start=2014, end=2020, ongoing=False
# Row 117 | Raw '2007-2012'
# Row 117 | Parsed: start=2007, end=2012, ongoing=False
# Row 118 | Raw '2016-2020'
# Row 118 | Parsed: start=2016, end=2020, ongoing=False
# Row 119 | Raw '2001-2010'
# Row 119 | Parsed: start=2001, end=2010, ongoing=False
# Row 120 | Raw '2020-'
# Row 120 | Parsed: start=2020, end=2025, ongoing=True
# Row 121 | Raw '2015-'
# Row 121 | Parsed: start=2015, end=2025, ongoing=True
# Row 122 | Raw '2011-2016'
# Row 122 | Parsed: start=2011, end=2016, ongoing=False
# Row 123 | Raw '2018-2020'
# Row 123 | Parsed: start=2018, end=2020, ongoing=False
# Row 124 | Raw '1998-2006'
# Row 124 | Parsed: start=1998, end=2006, ongoing=False
# Row 125 | Raw '2005-2007'
# Row 125 | Parsed: start=2005, end=2007, ongoing=False
# Row 126 | Raw '2007-2017'
# Row 126 | Parsed: start=2007, end=2017, ongoing=False
# Row 127 | Raw '2007-2014'
# Row 127 | Parsed: start=2007, end=2014, ongoing=False
# Row 128 | Raw '2022-'
# Row 128 | Parsed: start=2022, end=2025, ongoing=True
# Row 129 | Raw '2014-'
# Row 129 | Parsed: start=2014, end=2025, ongoing=True
# Row 130 | Raw '2022-2025'
# Row 130 | Parsed: start=2022, end=2025, ongoing=False
# Row 131 | Raw '2018-2023'
# Row 131 | Parsed: start=2018, end=2023, ongoing=False
# Row 132 | Raw '2021-'
# Row 132 | Parsed: start=2021, end=2025, ongoing=True
# Row 133 | Raw '2022-2025'
# Row 133 | Parsed: start=2022, end=2025, ongoing=False
# Row 134 | Raw '2010-2017'
# Row 134 | Parsed: start=2010, end=2017, ongoing=False
# Row 135 | Raw '2005-2017'
# Row 135 | Parsed: start=2005, end=2017, ongoing=False
# Row 136 | Raw '2015-2022'
# Row 136 | Parsed: start=2015, end=2022, ongoing=False
# Row 137 | Raw '2004-2009'
# Row 137 | Parsed: start=2004, end=2009, ongoing=False
# Row 138 | Raw '2019-'
# Row 138 | Parsed: start=2019, end=2025, ongoing=True
# Row 139 | Raw '2009-2016'
# Row 139 | Parsed: start=2009, end=2016, ongoing=False
# Row 140 | Raw '2004-2011'
# Row 140 | Parsed: start=2004, end=2011, ongoing=False
# Row 141 | Raw '2015-2022'
# Row 141 | Parsed: start=2015, end=2022, ongoing=False
# Row 142 | Raw '2023-'
# Row 142 | Parsed: start=2023, end=2025, ongoing=True
# Row 143 | Raw '2014-2019'
# Row 143 | Parsed: start=2014, end=2019, ongoing=False
# Row 144 | Raw '2014-2020'
# Row 144 | Parsed: start=2014, end=2020, ongoing=False
# Row 145 | Raw '2023-'
# Row 145 | Parsed: start=2023, end=2025, ongoing=True
# Row 146 | Raw '2009-2023'
# Row 146 | Parsed: start=2009, end=2023, ongoing=False
# Row 147 | Raw '2011-2017'
# Row 147 | Parsed: start=2011, end=2017, ongoing=False
# Row 148 | Raw '2006-2013'
# Row 148 | Parsed: start=2006, end=2013, ongoing=False
# Row 149 | Raw '2008-'
# Row 149 | Parsed: start=2008, end=2025, ongoing=True
# Row 150 | Raw '2003-'
# Row 150 | Parsed: start=2003, end=2025, ongoing=True
# Row 151 | Raw '2015-2018'
# Row 151 | Parsed: start=2015, end=2018, ongoing=False
# Row 152 | Raw '2016-2022'
# Row 152 | Parsed: start=2016, end=2022, ongoing=False
# Row 153 | Raw '1997-2003'
# Row 153 | Parsed: start=1997, end=2003, ongoing=False
# Row 154 | Raw '2019-2022'
# Row 154 | Parsed: start=2019, end=2022, ongoing=False
# Row 155 | Raw '1996-2003'
# Row 155 | Parsed: start=1996, end=2003, ongoing=False
# Row 156 | Raw '2017-2023'
# Row 156 | Parsed: start=2017, end=2023, ongoing=False
# Row 157 | Raw '2000-2007'
# Row 157 | Parsed: start=2000, end=2007, ongoing=False
# Row 158 | Raw '2024-'
# Row 158 | Parsed: start=2024, end=2025, ongoing=True
# Row 159 | Raw '2018'
# Row 159 | Parsed: start=2018, end=2018, ongoing=False
# Row 160 | Raw '1999-2000'
# Row 160 | Parsed: start=1999, end=2000, ongoing=False
# Row 161 | Raw '2015-2020'
# Row 161 | Parsed: start=2015, end=2020, ongoing=False
# Row 162 | Raw '2010-2019'
# Row 162 | Parsed: start=2010, end=2019, ongoing=False
# Row 163 | Raw '2009-2015'
# Row 163 | Parsed: start=2009, end=2015, ongoing=False
# Row 164 | Raw '2011-2014'
# Row 164 | Parsed: start=2011, end=2014, ongoing=False
# Row 165 | Raw '2024-2026'
# Row 165 | Parsed: start=2024, end=2026, ongoing=False
# Row 166 | Raw '2001-2005'
# Row 166 | Parsed: start=2001, end=2005, ongoing=False
# Row 167 | Raw '2000-2024'
# Row 167 | Parsed: start=2000, end=2024, ongoing=False
# Row 168 | Raw '2017'
# Row 168 | Parsed: start=2017, end=2017, ongoing=False
# Row 169 | Raw '2013-2018'
# Row 169 | Parsed: start=2013, end=2018, ongoing=False
# Row 170 | Raw '2012-2016'
# Row 170 | Parsed: start=2012, end=2016, ongoing=False
# Row 171 | Raw '2021-2024'
# Row 171 | Parsed: start=2021, end=2024, ongoing=False
# Row 172 | Raw '1998-2004'
# Row 172 | Parsed: start=1998, end=2004, ongoing=False
# Row 173 | Raw '1998-1999'
# Row 173 | Parsed: start=1998, end=1999, ongoing=False
# Row 174 | Raw '2007-2012'
# Row 174 | Parsed: start=2007, end=2012, ongoing=False
# Row 175 | Raw '2017-2023'
# Row 175 | Parsed: start=2017, end=2023, ongoing=False
# Row 176 | Raw '2015-2023'
# Row 176 | Parsed: start=2015, end=2023, ongoing=False
# Row 177 | Raw '2023-'
# Row 177 | Parsed: start=2023, end=2025, ongoing=True
# Row 178 | Raw '1990-1996'
# Row 178 | Parsed: start=1990, end=1996, ongoing=False
# Row 179 | Raw '2000-2006'
# Row 179 | Parsed: start=2000, end=2006, ongoing=False
# Row 180 | Raw '2009-2014'
# Row 180 | Parsed: start=2009, end=2014, ongoing=False
# Row 181 | Raw '2021-'
# Row 181 | Parsed: start=2021, end=2025, ongoing=True
# Row 182 | Raw '2020-'
# Row 182 | Parsed: start=2020, end=2025, ongoing=True
# Row 183 | Raw '2022-'
# Row 183 | Parsed: start=2022, end=2025, ongoing=True
# Row 184 | Raw '2004-2012'
# Row 184 | Parsed: start=2004, end=2012, ongoing=False
# Row 185 | Raw '2017-2021'
# Row 185 | Parsed: start=2017, end=2021, ongoing=False
# Row 186 | Raw '2018-2022'
# Row 186 | Parsed: start=2018, end=2022, ongoing=False
# Row 187 | Raw '2012-2014'
# Row 187 | Parsed: start=2012, end=2014, ongoing=False
# Row 188 | Raw '2017-2018'
# Row 188 | Parsed: start=2017, end=2018, ongoing=False
# Row 189 | Raw '2021-'
# Row 189 | Parsed: start=2021, end=2025, ongoing=True
# Row 190 | Raw '2016-2018'
# Row 190 | Parsed: start=2016, end=2018, ongoing=False
# Row 191 | Raw '2001-2017'
# Row 191 | Parsed: start=2001, end=2017, ongoing=False
# Row 192 | Raw '2002-2007'
# Row 192 | Parsed: start=2002, end=2007, ongoing=False
# Row 193 | Raw '1987-1994'
# Row 193 | Parsed: start=1987, end=1994, ongoing=False
# Row 194 | Raw '2017-2024'
# Row 194 | Parsed: start=2017, end=2024, ongoing=False
# Row 195 | Raw '1990-1995'
# Row 195 | Parsed: start=1990, end=1995, ongoing=False
# Row 196 | Raw '2005-'
# Row 196 | Parsed: start=2005, end=2025, ongoing=True
# Row 197 | Raw '2019-'
# Row 197 | Parsed: start=2019, end=2025, ongoing=True
# Row 198 | Raw '2023-'
# Row 198 | Parsed: start=2023, end=2025, ongoing=True
# Row 199 | Raw '2023'
# Row 199 | Parsed: start=2023, end=2023, ongoing=False
# Row 200 | Raw '2022-'
# Row 200 | Parsed: start=2022, end=2025, ongoing=True
# Row 201 | Raw '2011-2017'
# Row 201 | Parsed: start=2011, end=2017, ongoing=False
# Row 202 | Raw '2014-2016'
# Row 202 | Parsed: start=2014, end=2016, ongoing=False
# Row 203 | Raw '2006-2013'
# Row 203 | Parsed: start=2006, end=2013, ongoing=False
# Row 204 | Raw '1999-'
# Row 204 | Parsed: start=1999, end=2025, ongoing=True
# Row 205 | Raw '2013-2016'
# Row 205 | Parsed: start=2013, end=2016, ongoing=False
# Row 206 | Raw '2013-2017'
# Row 206 | Parsed: start=2013, end=2017, ongoing=False
# Row 207 | Raw '2015-2021'
# Row 207 | Parsed: start=2015, end=2021, ongoing=False
# Row 208 | Raw '2002-2022'
# Row 208 | Parsed: start=2002, end=2022, ongoing=False
# Row 209 | Raw '2018-2023'
# Row 209 | Parsed: start=2018, end=2023, ongoing=False
# Row 210 | Raw '2009-2011'
# Row 210 | Parsed: start=2009, end=2011, ongoing=False
# Row 211 | Raw '2024'
# Row 211 | Parsed: start=2024, end=2024, ongoing=False
# Row 212 | Raw '2020-'
# Row 212 | Parsed: start=2020, end=2025, ongoing=True
# Row 213 | Raw '2008-2020'
# Row 213 | Parsed: start=2008, end=2020, ongoing=False
# Row 214 | Raw '2012-2014'
# Row 214 | Parsed: start=2012, end=2014, ongoing=False
# Row 215 | Raw '2017-2024'
# Row 215 | Parsed: start=2017, end=2024, ongoing=False
# Row 216 | Raw '2011-2014'
# Row 216 | Parsed: start=2011, end=2014, ongoing=False
# Row 217 | Raw '2023-'
# Row 217 | Parsed: start=2023, end=2025, ongoing=True
# Row 218 | Raw '2001-2003'
# Row 218 | Parsed: start=2001, end=2003, ongoing=False
# Row 219 | Raw '2011-2015'
# Row 219 | Parsed: start=2011, end=2015, ongoing=False
# Row 220 | Raw '1992-1995'
# Row 220 | Parsed: start=1992, end=1995, ongoing=False
# Row 221 | Raw '2013-2016'
# Row 221 | Parsed: start=2013, end=2016, ongoing=False
# Row 222 | Raw '2010-2015'
# Row 222 | Parsed: start=2010, end=2015, ongoing=False
# Row 223 | Raw '2021-'
# Row 223 | Parsed: start=2021, end=2025, ongoing=True
# Row 224 | Raw '2004-2006'
# Row 224 | Parsed: start=2004, end=2006, ongoing=False
# Row 225 | Raw '2012-2019'
# Row 225 | Parsed: start=2012, end=2019, ongoing=False
# Row 226 | Raw '2017-2024'
# Row 226 | Parsed: start=2017, end=2024, ongoing=False
# Row 227 | Raw '2016-2019'
# Row 227 | Parsed: start=2016, end=2019, ongoing=False
# Row 228 | Raw '2010-2018'
# Row 228 | Parsed: start=2010, end=2018, ongoing=False
# Row 229 | Raw '2013-2017'
# Row 229 | Parsed: start=2013, end=2017, ongoing=False
# Row 230 | Raw '2014-2017'
# Row 230 | Parsed: start=2014, end=2017, ongoing=False
# Row 231 | Raw '2013-2017'
# Row 231 | Parsed: start=2013, end=2017, ongoing=False
# Row 232 | Raw '2014-2017'
# Row 232 | Parsed: start=2014, end=2017, ongoing=False
# Row 233 | Raw '2021-2023'
# Row 233 | Parsed: start=2021, end=2023, ongoing=False
# Row 234 | Raw '2005-2012'
# Row 234 | Parsed: start=2005, end=2012, ongoing=False
# Row 235 | Raw '2023-'
# Row 235 | Parsed: start=2023, end=2025, ongoing=True
# Row 236 | Raw '2019-2025'
# Row 236 | Parsed: start=2019, end=2025, ongoing=False
# Row 237 | Raw '1999-'
# Row 237 | Parsed: start=1999, end=2025, ongoing=True
# Row 238 | Raw '2019-2024'
# Row 238 | Parsed: start=2019, end=2024, ongoing=False
# Row 239 | Raw '2013-2018'
# Row 239 | Parsed: start=2013, end=2018, ongoing=False
# Row 240 | Raw '2015-2019'
# Row 240 | Parsed: start=2015, end=2019, ongoing=False
# Row 241 | Raw '2018-2023'
# Row 241 | Parsed: start=2018, end=2023, ongoing=False
# Row 242 | Raw '2022'
# Row 242 | Parsed: start=2022, end=2022, ongoing=False
# Row 243 | Raw '2013-2015'
# Row 243 | Parsed: start=2013, end=2015, ongoing=False
# Row 244 | Raw '2020-'
# Row 244 | Parsed: start=2020, end=2025, ongoing=True
# Row 245 | Raw '2006-2014'
# Row 245 | Parsed: start=2006, end=2014, ongoing=False
# Row 246 | Raw '1987-1997'
# Row 246 | Parsed: start=1987, end=1997, ongoing=False
# Row 247 | Raw '2023'
# Row 247 | Parsed: start=2023, end=2023, ongoing=False
# Row 248 | Raw '2022-'
# Row 248 | Parsed: start=2022, end=2025, ongoing=True
# Row 249 | Raw '2018-2020'
# Row 249 | Parsed: start=2018, end=2020, ongoing=False
# Row 250 | Raw '2016-2023'
# Row 250 | Parsed: start=2016, end=2023, ongoing=False
# Row 251 | Raw '2005-2009'
# Row 251 | Parsed: start=2005, end=2009, ongoing=False
# Row 252 | Raw '2016-2022'
# Row 252 | Parsed: start=2016, end=2022, ongoing=False
# Row 253 | Raw '2019-2022'
# Row 253 | Parsed: start=2019, end=2022, ongoing=False
# Row 254 | Raw '1997-2003'
# Row 254 | Parsed: start=1997, end=2003, ongoing=False
# Row 255 | Raw '2016-2019'
# Row 255 | Parsed: start=2016, end=2019, ongoing=False
# Row 256 | Raw '2009-2013'
# Row 256 | Parsed: start=2009, end=2013, ongoing=False
# Row 257 | Raw '2016-2025'
# Row 257 | Parsed: start=2016, end=2025, ongoing=False
# Row 258 | Raw '2011-2017'
# Row 258 | Parsed: start=2011, end=2017, ongoing=False
# Row 259 | Raw '2018-2021'
# Row 259 | Parsed: start=2018, end=2021, ongoing=False
# Row 260 | Raw '2017-2021'
# Row 260 | Parsed: start=2017, end=2021, ongoing=False
# Row 261 | Raw '2022-'
# Row 261 | Parsed: start=2022, end=2025, ongoing=True
# Row 262 | Raw '2021-'
# Row 262 | Parsed: start=2021, end=2025, ongoing=True
# Row 263 | Raw '2020'
# Row 263 | Parsed: start=2020, end=2020, ongoing=False
# Row 264 | Raw '2015-2018'
# Row 264 | Parsed: start=2015, end=2018, ongoing=False
# Row 265 | Raw '2019-2022'
# Row 265 | Parsed: start=2019, end=2022, ongoing=False
# Row 266 | Raw '1975-1979'
# Row 266 | Parsed: start=1975, end=1979, ongoing=False
# Row 267 | Raw '1997-2007'
# Row 267 | Parsed: start=1997, end=2007, ongoing=False
# Row 268 | Raw '2017-2022'
# Row 268 | Parsed: start=2017, end=2022, ongoing=False
# Row 269 | Raw '2019-2022'
# Row 269 | Parsed: start=2019, end=2022, ongoing=False
# Row 270 | Raw '2019-'
# Row 270 | Parsed: start=2019, end=2025, ongoing=True
# Row 271 | Raw '2020-2022'
# Row 271 | Parsed: start=2020, end=2022, ongoing=False
# Row 272 | Raw '2022-2024'
# Row 272 | Parsed: start=2022, end=2024, ongoing=False
# Row 273 | Raw '2020-'
# Row 273 | Parsed: start=2020, end=2025, ongoing=True
# Row 274 | Raw '2016-'
# Row 274 | Parsed: start=2016, end=2025, ongoing=True
# Row 275 | Raw '2017-2019'
# Row 275 | Parsed: start=2017, end=2019, ongoing=False
# Row 276 | Raw '2021-'
# Row 276 | Parsed: start=2021, end=2025, ongoing=True
# Row 277 | Raw '1959-1964'
# Row 277 | Parsed: start=1959, end=1964, ongoing=False
# Row 278 | Raw '2014-'
# Row 278 | Parsed: start=2014, end=2025, ongoing=True
# Row 279 | Raw '2003-2007'
# Row 279 | Parsed: start=2003, end=2007, ongoing=False
# Row 280 | Raw '2011-2023'
# Row 280 | Parsed: start=2011, end=2023, ongoing=False
# Row 281 | Raw '1993-2004'
# Row 281 | Parsed: start=1993, end=2004, ongoing=False
# Row 282 | Raw '2020-2023'
# Row 282 | Parsed: start=2020, end=2023, ongoing=False
# Row 283 | Raw '2002-2009'
# Row 283 | Parsed: start=2002, end=2009, ongoing=False
# Row 284 | Raw '2008-2010'
# Row 284 | Parsed: start=2008, end=2010, ongoing=False
# Row 285 | Raw '2018-2023'
# Row 285 | Parsed: start=2018, end=2023, ongoing=False
# Row 286 | Raw '2011-'
# Row 286 | Parsed: start=2011, end=2025, ongoing=True
# Row 287 | Raw '2018-2021'
# Row 287 | Parsed: start=2018, end=2021, ongoing=False
# Row 288 | Raw '2007-2013'
# Row 288 | Parsed: start=2007, end=2013, ongoing=False
# Row 289 | Raw '1966-1969'
# Row 289 | Parsed: start=1966, end=1969, ongoing=False
# Row 290 | Raw '2013-2020'
# Row 290 | Parsed: start=2013, end=2020, ongoing=False
# Row 291 | Raw '2018-2024'
# Row 291 | Parsed: start=2018, end=2024, ongoing=False
# Row 292 | Raw '2023-'
# Row 292 | Parsed: start=2023, end=2025, ongoing=True
# Row 293 | Raw '2022-'
# Row 293 | Parsed: start=2022, end=2025, ongoing=True
# Row 294 | Raw '2017-2021'
# Row 294 | Parsed: start=2017, end=2021, ongoing=False
# Row 295 | Raw '1995-1996'
# Row 295 | Parsed: start=1995, end=1996, ongoing=False
# Row 296 | Raw '2018-2019'
# Row 296 | Parsed: start=2018, end=2019, ongoing=False
# Row 297 | Raw '1998-2006'
# Row 297 | Parsed: start=1998, end=2006, ongoing=False
# Row 298 | Raw '1989-1996'
# Row 298 | Parsed: start=1989, end=1996, ongoing=False
# Row 299 | Raw '2011-2015'
# Row 299 | Parsed: start=2011, end=2015, ongoing=False
# Row 300 | Raw '2019-2023'
# Row 300 | Parsed: start=2019, end=2023, ongoing=False
# Row 301 | Raw '2020-'
# Row 301 | Parsed: start=2020, end=2025, ongoing=True
# Row 302 | Raw '2016-2022'
# Row 302 | Parsed: start=2016, end=2022, ongoing=False
# Row 303 | Raw '2013-2015'
# Row 303 | Parsed: start=2013, end=2015, ongoing=False
# Row 304 | Raw '2017-2025'
# Row 304 | Parsed: start=2017, end=2025, ongoing=False
# Row 305 | Raw '2018-'
# Row 305 | Parsed: start=2018, end=2025, ongoing=True
# Row 306 | Raw '2002-2008'
# Row 306 | Parsed: start=2002, end=2008, ongoing=False
# Row 307 | Raw '2000-2015'
# Row 307 | Parsed: start=2000, end=2015, ongoing=False
# Row 308 | Raw '2015-2016'
# Row 308 | Parsed: start=2015, end=2016, ongoing=False
# Row 309 | Raw '1999-2006'
# Row 309 | Parsed: start=1999, end=2006, ongoing=False
# Row 310 | Raw '1998-2007'
# Row 310 | Parsed: start=1998, end=2007, ongoing=False
# Row 311 | Raw '2003-2012'
# Row 311 | Parsed: start=2003, end=2012, ongoing=False
# Row 312 | Raw '2020-2022'
# Row 312 | Parsed: start=2020, end=2022, ongoing=False
# Row 313 | Raw '2016-2024'
# Row 313 | Parsed: start=2016, end=2024, ongoing=False
# Row 314 | Raw '2008-2012'
# Row 314 | Parsed: start=2008, end=2012, ongoing=False
# Row 315 | Raw '2014-2017'
# Row 315 | Parsed: start=2014, end=2017, ongoing=False
# Row 316 | Raw '2019-2022'
# Row 316 | Parsed: start=2019, end=2022, ongoing=False
# Row 317 | Raw '2016-'
# Row 317 | Parsed: start=2016, end=2025, ongoing=True
# Row 318 | Raw '2021-'
# Row 318 | Parsed: start=2021, end=2025, ongoing=True
# Row 319 | Raw '2018-'
# Row 319 | Parsed: start=2018, end=2025, ongoing=True
# Row 320 | Raw '2020-2021'
# Row 320 | Parsed: start=2020, end=2021, ongoing=False
# Row 321 | Raw '2006-2008'
# Row 321 | Parsed: start=2006, end=2008, ongoing=False
# Row 322 | Raw '2024-'
# Row 322 | Parsed: start=2024, end=2025, ongoing=True
# Row 323 | Raw '2023-'
# Row 323 | Parsed: start=2023, end=2025, ongoing=True
# Row 324 | Raw '2014-2021'
# Row 324 | Parsed: start=2014, end=2021, ongoing=False
# Row 325 | Raw '2017-2021'
# Row 325 | Parsed: start=2017, end=2021, ongoing=False
# Row 326 | Raw '2011'
# Row 326 | Parsed: start=2011, end=2011, ongoing=False
# Row 327 | Raw '2019-2021'
# Row 327 | Parsed: start=2019, end=2021, ongoing=False
# Row 328 | Raw '2012-2014'
# Row 328 | Parsed: start=2012, end=2014, ongoing=False
# Row 329 | Raw '2020-2023'
# Row 329 | Parsed: start=2020, end=2023, ongoing=False
# Row 330 | Raw '2022-'
# Row 330 | Parsed: start=2022, end=2025, ongoing=True
# Row 331 | Raw '2022'
# Row 331 | Parsed: start=2022, end=2022, ongoing=False
# Row 332 | Raw '2022-'
# Row 332 | Parsed: start=2022, end=2025, ongoing=True
# Row 333 | Raw '2009-2016'
# Row 333 | Parsed: start=2009, end=2016, ongoing=False
# Row 334 | Raw '2019-2023'
# Row 334 | Parsed: start=2019, end=2023, ongoing=False
# Row 335 | Raw '2016-2019'
# Row 335 | Parsed: start=2016, end=2019, ongoing=False
# Row 336 | Raw '2007-2010'
# Row 336 | Parsed: start=2007, end=2010, ongoing=False
# Row 337 | Raw '2010-2015'
# Row 337 | Parsed: start=2010, end=2015, ongoing=False
# Row 338 | Raw '2020-'
# Row 338 | Parsed: start=2020, end=2025, ongoing=True
# Row 339 | Raw '2024-'
# Row 339 | Parsed: start=2024, end=2025, ongoing=True
# Row 340 | Raw '2015-2018'
# Row 340 | Parsed: start=2015, end=2018, ongoing=False
# Row 341 | Raw '1969-1974'
# Row 341 | Parsed: start=1969, end=1974, ongoing=False
# Row 342 | Raw '2017'
# Row 342 | Parsed: start=2017, end=2017, ongoing=False
# Row 343 | Raw '2012-2018'
# Row 343 | Parsed: start=2012, end=2018, ongoing=False
# Row 344 | Raw '2014-2016'
# Row 344 | Parsed: start=2014, end=2016, ongoing=False
# Row 345 | Raw '2003-2004'
# Row 345 | Parsed: start=2003, end=2004, ongoing=False
# Row 346 | Raw '2015-2020'
# Row 346 | Parsed: start=2015, end=2020, ongoing=False
# Row 347 | Raw '2011-2015'
# Row 347 | Parsed: start=2011, end=2015, ongoing=False
# Row 348 | Raw '2015-2019'
# Row 348 | Parsed: start=2015, end=2019, ongoing=False
# Row 349 | Raw '2007-2013'
# Row 349 | Parsed: start=2007, end=2013, ongoing=False
# Row 350 | Raw '2010-2020'
# Row 350 | Parsed: start=2010, end=2020, ongoing=False
# Row 351 | Raw '2011-2018'
# Row 351 | Parsed: start=2011, end=2018, ongoing=False
# Row 352 | Raw '1995-2001'
# Row 352 | Parsed: start=1995, end=2001, ongoing=False
# Row 353 | Raw '2022-'
# Row 353 | Parsed: start=2022, end=2025, ongoing=True
# Row 354 | Raw '2013-2015'
# Row 354 | Parsed: start=2013, end=2015, ongoing=False
# Row 355 | Raw '2023-2024'
# Row 355 | Parsed: start=2023, end=2024, ongoing=False
# Row 356 | Raw '2004-2019'
# Row 356 | Parsed: start=2004, end=2019, ongoing=False
# Row 357 | Raw '2012-2017'
# Row 357 | Parsed: start=2012, end=2017, ongoing=False
# Row 358 | Raw '2004-2023'
# Row 358 | Parsed: start=2004, end=2023, ongoing=False
# Row 359 | Raw '1996-2005'
# Row 359 | Parsed: start=1996, end=2005, ongoing=False
# Row 360 | Raw '2017-2019'
# Row 360 | Parsed: start=2017, end=2019, ongoing=False
# Row 361 | Raw '2023-2025'
# Row 361 | Parsed: start=2023, end=2025, ongoing=False
# Row 362 | Raw '2023-'
# Row 362 | Parsed: start=2023, end=2025, ongoing=True
# Row 363 | Raw '2024-'
# Row 363 | Parsed: start=2024, end=2025, ongoing=True
# Row 364 | Raw '2020'
# Row 364 | Parsed: start=2020, end=2020, ongoing=False
# Row 365 | Raw '2019-'
# Row 365 | Parsed: start=2019, end=2025, ongoing=True
# Row 366 | Raw '2015-2019'
# Row 366 | Parsed: start=2015, end=2019, ongoing=False
# Row 367 | Raw '1999-2004'
# Row 367 | Parsed: start=1999, end=2004, ongoing=False
# Row 368 | Raw '2015-2021'
# Row 368 | Parsed: start=2015, end=2021, ongoing=False
# Row 369 | Raw '2015-2019'
# Row 369 | Parsed: start=2015, end=2019, ongoing=False
# Row 370 | Raw '2022-'
# Row 370 | Parsed: start=2022, end=2025, ongoing=True
# Row 371 | Raw '2024'
# Row 371 | Parsed: start=2024, end=2024, ongoing=False
# Row 372 | Raw '2023'
# Row 372 | Parsed: start=2023, end=2023, ongoing=False
# Row 373 | Raw '2018-2023'
# Row 373 | Parsed: start=2018, end=2023, ongoing=False
# Row 374 | Raw '2020-2023'
# Row 374 | Parsed: start=2020, end=2023, ongoing=False
# Row 375 | Raw '2015-2021'
# Row 375 | Parsed: start=2015, end=2021, ongoing=False
# Row 376 | Raw '2003-2006'
# Row 376 | Parsed: start=2003, end=2006, ongoing=False
# Row 377 | Raw '2006-2011'
# Row 377 | Parsed: start=2006, end=2011, ongoing=False
# Row 378 | Raw '2021-2024'
# Row 378 | Parsed: start=2021, end=2024, ongoing=False
# Row 379 | Raw '2015-2022'
# Row 379 | Parsed: start=2015, end=2022, ongoing=False
# Row 380 | Raw '2020'
# Row 380 | Parsed: start=2020, end=2020, ongoing=False
# Row 381 | Raw '2020'
# Row 381 | Parsed: start=2020, end=2020, ongoing=False
# Row 382 | Raw '2012-2021'
# Row 382 | Parsed: start=2012, end=2021, ongoing=False
# Row 383 | Raw '1993-1999'
# Row 383 | Parsed: start=1993, end=1999, ongoing=False
# Row 384 | Raw '2004-2009'
# Row 384 | Parsed: start=2004, end=2009, ongoing=False
# Row 385 | Raw '2015-2016'
# Row 385 | Parsed: start=2015, end=2016, ongoing=False
# Row 386 | Raw '2016-2019'
# Row 386 | Parsed: start=2016, end=2019, ongoing=False
# Row 387 | Raw '2023-'
# Row 387 | Parsed: start=2023, end=2025, ongoing=True
# Row 388 | Raw '2020-2022'
# Row 388 | Parsed: start=2020, end=2022, ongoing=False
# Row 389 | Raw '2017-2019'
# Row 389 | Parsed: start=2017, end=2019, ongoing=False
# Row 390 | Raw '2022'
# Row 390 | Parsed: start=2022, end=2022, ongoing=False
# Row 391 | Raw '2020-'
# Row 391 | Parsed: start=2020, end=2025, ongoing=True
# Row 392 | Raw '1986-1989'
# Row 392 | Parsed: start=1986, end=1989, ongoing=False
# Row 393 | Raw '1994-2009'
# Row 393 | Parsed: start=1994, end=2009, ongoing=False
# Row 394 | Raw '2021-'
# Row 394 | Parsed: start=2021, end=2025, ongoing=True
# Row 395 | Raw '2021-'
# Row 395 | Parsed: start=2021, end=2025, ongoing=True
# Row 396 | Raw '2003-2015'
# Row 396 | Parsed: start=2003, end=2015, ongoing=False
# Row 397 | Raw '2023-'
# Row 397 | Parsed: start=2023, end=2025, ongoing=True
# Row 398 | Raw '2020-2024'
# Row 398 | Parsed: start=2020, end=2024, ongoing=False
# Row 399 | Raw '1995-2003'
# Row 399 | Parsed: start=1995, end=2003, ongoing=False
# Row 400 | Raw '2017-2019'
# Row 400 | Parsed: start=2017, end=2019, ongoing=False
# Row 401 | Raw '2014-2023'
# Row 401 | Parsed: start=2014, end=2023, ongoing=False
# Row 402 | Raw '2016-2018'
# Row 402 | Parsed: start=2016, end=2018, ongoing=False
# Row 403 | Raw '2012-'
# Row 403 | Parsed: start=2012, end=2025, ongoing=True
# Row 404 | Raw '2022-2025'
# Row 404 | Parsed: start=2022, end=2025, ongoing=False
# Row 405 | Raw '2007-2009'
# Row 405 | Parsed: start=2007, end=2009, ongoing=False
# Row 406 | Raw '2020-'
# Row 406 | Parsed: start=2020, end=2025, ongoing=True
# Row 407 | Raw '2018-2022'
# Row 407 | Parsed: start=2018, end=2022, ongoing=False
# Row 408 | Raw '2012-2019'
# Row 408 | Parsed: start=2012, end=2019, ongoing=False
# Row 409 | Raw '2018-2022'
# Row 409 | Parsed: start=2018, end=2022, ongoing=False
# Row 410 | Raw '2009-2013'
# Row 410 | Parsed: start=2009, end=2013, ongoing=False
# Row 411 | Raw '1972-1983'
# Row 411 | Parsed: start=1972, end=1983, ongoing=False
# Row 412 | Raw '2022-2024'
# Row 412 | Parsed: start=2022, end=2024, ongoing=False
# Row 413 | Raw '2014-2018'
# Row 413 | Parsed: start=2014, end=2018, ongoing=False
# Row 414 | Raw '2015-2018'
# Row 414 | Parsed: start=2015, end=2018, ongoing=False
# Row 415 | Raw '2013-2017'
# Row 415 | Parsed: start=2013, end=2017, ongoing=False
# Row 416 | Raw '2017-2020'
# Row 416 | Parsed: start=2017, end=2020, ongoing=False
# Row 417 | Raw '2012-2015'
# Row 417 | Parsed: start=2012, end=2015, ongoing=False
# Row 418 | Raw '2010-2017'
# Row 418 | Parsed: start=2010, end=2017, ongoing=False
# Row 419 | Raw '1987-1995'
# Row 419 | Parsed: start=1987, end=1995, ongoing=False
# Row 420 | Raw '2016-2017'
# Row 420 | Parsed: start=2016, end=2017, ongoing=False
# Row 421 | Raw '2015-2018'
# Row 421 | Parsed: start=2015, end=2018, ongoing=False
# Row 422 | Raw '2020-2022'
# Row 422 | Parsed: start=2020, end=2022, ongoing=False
# Row 423 | Raw '1982-1993'
# Row 423 | Parsed: start=1982, end=1993, ongoing=False
# Row 424 | Raw '2018-2021'
# Row 424 | Parsed: start=2018, end=2021, ongoing=False
# Row 425 | Raw '2014-2015'
# Row 425 | Parsed: start=2014, end=2015, ongoing=False
# Row 426 | Raw '2021'
# Row 426 | Parsed: start=2021, end=2021, ongoing=False
# Row 427 | Raw '2008-2009'
# Row 427 | Parsed: start=2008, end=2009, ongoing=False
# Row 428 | Raw '2022-'
# Row 428 | Parsed: start=2022, end=2025, ongoing=True
# Row 429 | Raw '2022'
# Row 429 | Parsed: start=2022, end=2022, ongoing=False
# Row 430 | Raw '1997-1998'
# Row 430 | Parsed: start=1997, end=1998, ongoing=False
# Row 431 | Raw '2000-2004'
# Row 431 | Parsed: start=2000, end=2004, ongoing=False
# Row 432 | Raw '2001-2017'
# Row 432 | Parsed: start=2001, end=2017, ongoing=False
# Row 433 | Raw '2002-2012'
# Row 433 | Parsed: start=2002, end=2012, ongoing=False
# Row 434 | Raw '2009-2010'
# Row 434 | Parsed: start=2009, end=2010, ongoing=False
# Row 435 | Raw '2018-2020'
# Row 435 | Parsed: start=2018, end=2020, ongoing=False
# Row 436 | Raw '2014-2018'
# Row 436 | Parsed: start=2014, end=2018, ongoing=False
# Row 437 | Raw '2015-2016'
# Row 437 | Parsed: start=2015, end=2016, ongoing=False
# Row 438 | Raw '1998-2020'
# Row 438 | Parsed: start=1998, end=2020, ongoing=False
# Row 439 | Raw '2014-2019'
# Row 439 | Parsed: start=2014, end=2019, ongoing=False
# Row 440 | Raw '2005-2007'
# Row 440 | Parsed: start=2005, end=2007, ongoing=False
# Row 441 | Raw '2014-2018'
# Row 441 | Parsed: start=2014, end=2018, ongoing=False
# Row 442 | Raw '2019-2023'
# Row 442 | Parsed: start=2019, end=2023, ongoing=False
# Row 443 | Raw '2001-2005'
# Row 443 | Parsed: start=2001, end=2005, ongoing=False
# Row 444 | Raw '2021-'
# Row 444 | Parsed: start=2021, end=2025, ongoing=True
# Row 445 | Raw '2015-2017'
# Row 445 | Parsed: start=2015, end=2017, ongoing=False
# Row 446 | Raw '2021-2022'
# Row 446 | Parsed: start=2021, end=2022, ongoing=False
# Row 447 | Raw '2007-'
# Row 447 | Parsed: start=2007, end=2025, ongoing=True
# Row 448 | Raw '2010-2011'
# Row 448 | Parsed: start=2010, end=2011, ongoing=False
# Row 449 | Raw '1997-2026'
# Row 449 | Parsed: start=1997, end=2026, ongoing=False
# Row 450 | Raw '2007-2009'
# Row 450 | Parsed: start=2007, end=2009, ongoing=False
# Row 451 | Raw '2021-2024'
# Row 451 | Parsed: start=2021, end=2024, ongoing=False
# Row 452 | Raw '1981-2003'
# Row 452 | Parsed: start=1981, end=2003, ongoing=False
# Row 453 | Raw '2024-'
# Row 453 | Parsed: start=2024, end=2025, ongoing=True
# Row 454 | Raw '2022'
# Row 454 | Parsed: start=2022, end=2022, ongoing=False
# Row 455 | Raw '1989'
# Row 455 | Parsed: start=1989, end=1989, ongoing=False
# Row 456 | Raw '2006-2012'
# Row 456 | Parsed: start=2006, end=2012, ongoing=False
# Row 457 | Raw '2003-2010'
# Row 457 | Parsed: start=2003, end=2010, ongoing=False
# Row 458 | Raw '2021-'
# Row 458 | Parsed: start=2021, end=2025, ongoing=True
# Row 459 | Raw '2009-2011'
# Row 459 | Parsed: start=2009, end=2011, ongoing=False
# Row 460 | Raw '2006-2008'
# Row 460 | Parsed: start=2006, end=2008, ongoing=False
# Row 461 | Raw '2016-2017'
# Row 461 | Parsed: start=2016, end=2017, ongoing=False
# Row 462 | Raw '1999-2001'
# Row 462 | Parsed: start=1999, end=2001, ongoing=False
# Row 463 | Raw '2022-2024'
# Row 463 | Parsed: start=2022, end=2024, ongoing=False
# Row 464 | Raw '2009-2014'
# Row 464 | Parsed: start=2009, end=2014, ongoing=False
# Row 465 | Raw '2015-2022'
# Row 465 | Parsed: start=2015, end=2022, ongoing=False
# Row 466 | Raw '2004-2005'
# Row 466 | Parsed: start=2004, end=2005, ongoing=False
# Row 467 | Raw '2009-2023'
# Row 467 | Parsed: start=2009, end=2023, ongoing=False
# Row 468 | Raw '2020-2023'
# Row 468 | Parsed: start=2020, end=2023, ongoing=False
# Row 469 | Raw '2016-2021'
# Row 469 | Parsed: start=2016, end=2021, ongoing=False
# Row 470 | Raw '2019-2020'
# Row 470 | Parsed: start=2019, end=2020, ongoing=False
# Row 471 | Raw '2024-'
# Row 471 | Parsed: start=2024, end=2025, ongoing=True
# Row 472 | Raw '2021-'
# Row 472 | Parsed: start=2021, end=2025, ongoing=True
# Row 473 | Raw '2022-'
# Row 473 | Parsed: start=2022, end=2025, ongoing=True
# Row 474 | Raw '2020-'
# Row 474 | Parsed: start=2020, end=2025, ongoing=True
# Row 475 | Raw '2015-2020'
# Row 475 | Parsed: start=2015, end=2020, ongoing=False
# Row 476 | Raw '2011-2015'
# Row 476 | Parsed: start=2011, end=2015, ongoing=False
# Row 477 | Raw '2011-2016'
# Row 477 | Parsed: start=2011, end=2016, ongoing=False
# Row 478 | Raw '2011-2017'
# Row 478 | Parsed: start=2011, end=2017, ongoing=False
# Row 479 | Raw '2018-2025'
# Row 479 | Parsed: start=2018, end=2025, ongoing=False
# Row 480 | Raw '2014-2015'
# Row 480 | Parsed: start=2014, end=2015, ongoing=False
# Row 481 | Raw '2020-2022'
# Row 481 | Parsed: start=2020, end=2022, ongoing=False
# Row 482 | Raw '2022-2025'
# Row 482 | Parsed: start=2022, end=2025, ongoing=False
# Row 483 | Raw '1996-2001'
# Row 483 | Parsed: start=1996, end=2001, ongoing=False
# Row 484 | Raw '2024-'
# Row 484 | Parsed: start=2024, end=2025, ongoing=True
# Row 485 | Raw '2012-'
# Row 485 | Parsed: start=2012, end=2025, ongoing=True
# Row 486 | Raw '2024-'
# Row 486 | Parsed: start=2024, end=2025, ongoing=True
# Row 487 | Raw '2009-2018'
# Row 487 | Parsed: start=2009, end=2018, ongoing=False
# Row 488 | Raw '2013-2017'
# Row 488 | Parsed: start=2013, end=2017, ongoing=False
# Row 489 | Raw '2001-2006'
# Row 489 | Parsed: start=2001, end=2006, ongoing=False
# Row 490 | Raw '2019-2023'
# Row 490 | Parsed: start=2019, end=2023, ongoing=False
# Row 491 | Raw '2019-'
# Row 491 | Parsed: start=2019, end=2025, ongoing=True
# Row 492 | Raw '2015-2024'
# Row 492 | Parsed: start=2015, end=2024, ongoing=False
# Row 493 | Raw '2003-2018'
# Row 493 | Parsed: start=2003, end=2018, ongoing=False
# Row 494 | Raw '1996-2003'
# Row 494 | Parsed: start=1996, end=2003, ongoing=False
# Row 495 | Raw '2023-'
# Row 495 | Parsed: start=2023, end=2025, ongoing=True
# Row 496 | Raw '2008-2012'
# Row 496 | Parsed: start=2008, end=2012, ongoing=False
# Row 497 | Raw '2023-'
# Row 497 | Parsed: start=2023, end=2025, ongoing=True
# Row 498 | Raw '1989-2013'
# Row 498 | Parsed: start=1989, end=2013, ongoing=False
# Row 499 | Raw '2014-2020'
# Row 499 | Parsed: start=2014, end=2020, ongoing=False
# Row 500 | Raw '1975-'
# Row 500 | Parsed: start=1975, end=2025, ongoing=True
# Row 501 | Raw '2011-2013'
# Row 501 | Parsed: start=2011, end=2013, ongoing=False
# Row 502 | Raw '2019-2022'
# Row 502 | Parsed: start=2019, end=2022, ongoing=False
# Row 503 | Raw '2010-2013'
# Row 503 | Parsed: start=2010, end=2013, ongoing=False
# Row 504 | Raw '2017-'
# Row 504 | Parsed: start=2017, end=2025, ongoing=True
# Row 505 | Raw '2004-2005'
# Row 505 | Parsed: start=2004, end=2005, ongoing=False
# Row 506 | Raw '2019-'
# Row 506 | Parsed: start=2019, end=2025, ongoing=True
# Row 507 | Raw '2014-2015'
# Row 507 | Parsed: start=2014, end=2015, ongoing=False
# Row 508 | Raw '2001-2004'
# Row 508 | Parsed: start=2001, end=2004, ongoing=False
# Row 509 | Raw '2009-2011'
# Row 509 | Parsed: start=2009, end=2011, ongoing=False
# Row 510 | Raw '2014-2015'
# Row 510 | Parsed: start=2014, end=2015, ongoing=False
# Row 511 | Raw '2020-2023'
# Row 511 | Parsed: start=2020, end=2023, ongoing=False
# Row 512 | Raw '2001-2018'
# Row 512 | Parsed: start=2001, end=2018, ongoing=False
# Row 513 | Raw '2018-2019'
# Row 513 | Parsed: start=2018, end=2019, ongoing=False
# Row 514 | Raw '1999-2002'
# Row 514 | Parsed: start=1999, end=2002, ongoing=False
# Row 515 | Raw '2018-'
# Row 515 | Parsed: start=2018, end=2025, ongoing=True
# Row 516 | Raw '2016-2022'
# Row 516 | Parsed: start=2016, end=2022, ongoing=False
# Row 517 | Raw '2013-2014'
# Row 517 | Parsed: start=2013, end=2014, ongoing=False
# Row 518 | Raw '2023-'
# Row 518 | Parsed: start=2023, end=2025, ongoing=True
# Row 519 | Raw '2009-2015'
# Row 519 | Parsed: start=2009, end=2015, ongoing=False
# Row 520 | Raw '2018-2022'
# Row 520 | Parsed: start=2018, end=2022, ongoing=False
# Row 521 | Raw '2013-2014'
# Row 521 | Parsed: start=2013, end=2014, ongoing=False
# Row 522 | Raw '2009-2010'
# Row 522 | Parsed: start=2009, end=2010, ongoing=False
# Row 523 | Raw '2017-2019'
# Row 523 | Parsed: start=2017, end=2019, ongoing=False
# Row 524 | Raw '2022-2024'
# Row 524 | Parsed: start=2022, end=2024, ongoing=False
# Row 525 | Raw '1992-1997'
# Row 525 | Parsed: start=1992, end=1997, ongoing=False
# Row 526 | Raw '1986'
# Row 526 | Parsed: start=1986, end=1986, ongoing=False
# Row 527 | Raw '1993-1999'
# Row 527 | Parsed: start=1993, end=1999, ongoing=False
# Row 528 | Raw '2019-2021'
# Row 528 | Parsed: start=2019, end=2021, ongoing=False
# Row 529 | Raw '2020-2023'
# Row 529 | Parsed: start=2020, end=2023, ongoing=False
# Row 530 | Raw '2004-2008'
# Row 530 | Parsed: start=2004, end=2008, ongoing=False
# Row 531 | Raw '2010-2024'
# Row 531 | Parsed: start=2010, end=2024, ongoing=False
# Row 532 | Raw '2018-'
# Row 532 | Parsed: start=2018, end=2025, ongoing=True
# Row 533 | Raw '2005-2010'
# Row 533 | Parsed: start=2005, end=2010, ongoing=False
# Row 534 | Raw '2015-2019'
# Row 534 | Parsed: start=2015, end=2019, ongoing=False
# Row 535 | Raw '1991-1999'
# Row 535 | Parsed: start=1991, end=1999, ongoing=False
# Row 536 | Raw '2019-2025'
# Row 536 | Parsed: start=2019, end=2025, ongoing=False
# Row 537 | Raw '2015-2018'
# Row 537 | Parsed: start=2015, end=2018, ongoing=False
# Row 538 | Raw '1997-2023'
# Row 538 | Parsed: start=1997, end=2023, ongoing=False
# Row 539 | Raw '2004-2013'
# Row 539 | Parsed: start=2004, end=2013, ongoing=False
# Row 540 | Raw '2014-2019'
# Row 540 | Parsed: start=2014, end=2019, ongoing=False
# Row 541 | Raw '1995-2001'
# Row 541 | Parsed: start=1995, end=2001, ongoing=False
# Row 542 | Raw '2024-'
# Row 542 | Parsed: start=2024, end=2025, ongoing=True
# Row 543 | Raw '2019-2023'
# Row 543 | Parsed: start=2019, end=2023, ongoing=False
# Row 544 | Raw '2023-'
# Row 544 | Parsed: start=2023, end=2025, ongoing=True
# Row 545 | Raw '2023'
# Row 545 | Parsed: start=2023, end=2023, ongoing=False
# Row 546 | Raw '1998-2004'
# Row 546 | Parsed: start=1998, end=2004, ongoing=False
# Row 547 | Raw '2024-'
# Row 547 | Parsed: start=2024, end=2025, ongoing=True
# Row 548 | Raw '1985-1992'
# Row 548 | Parsed: start=1985, end=1992, ongoing=False
# Row 549 | Raw '2018-2021'
# Row 549 | Parsed: start=2018, end=2021, ongoing=False
# Row 550 | Raw '2021-'
# Row 550 | Parsed: start=2021, end=2025, ongoing=True
# Row 551 | Raw '2011-2012'
# Row 551 | Parsed: start=2011, end=2012, ongoing=False
# Row 552 | Raw '2019-2020'
# Row 552 | Parsed: start=2019, end=2020, ongoing=False
# Row 553 | Raw '2006-2010'
# Row 553 | Parsed: start=2006, end=2010, ongoing=False
# Row 554 | Raw '2019-2023'
# Row 554 | Parsed: start=2019, end=2023, ongoing=False
# Row 555 | Raw '2000-2004'
# Row 555 | Parsed: start=2000, end=2004, ongoing=False
# Row 556 | Raw '2001-2017'
# Row 556 | Parsed: start=2001, end=2017, ongoing=False
# Row 557 | Raw '1987'
# Row 557 | Parsed: start=1987, end=1987, ongoing=False
# Row 558 | Raw '2020'
# Row 558 | Parsed: start=2020, end=2020, ongoing=False
# Row 559 | Raw '2024-'
# Row 559 | Parsed: start=2024, end=2025, ongoing=True
# Row 560 | Raw '1996-'
# Row 560 | Parsed: start=1996, end=2025, ongoing=True
# Row 561 | Raw '2011-'
# Row 561 | Parsed: start=2011, end=2025, ongoing=True
# Row 562 | Raw '2015-2016'
# Row 562 | Parsed: start=2015, end=2016, ongoing=False
# Row 563 | Raw '2016-2018'
# Row 563 | Parsed: start=2016, end=2018, ongoing=False
# Row 564 | Raw '2021-2025'
# Row 564 | Parsed: start=2021, end=2025, ongoing=False
# Row 565 | Raw '2014-'
# Row 565 | Parsed: start=2014, end=2025, ongoing=True
# Row 566 | Raw '2023-'
# Row 566 | Parsed: start=2023, end=2025, ongoing=True
# Row 567 | Raw '2022-'
# Row 567 | Parsed: start=2022, end=2025, ongoing=True
# Row 568 | Raw '2020'
# Row 568 | Parsed: start=2020, end=2020, ongoing=False
# Row 569 | Raw '2010-2022'
# Row 569 | Parsed: start=2010, end=2022, ongoing=False
# Row 570 | Raw '2022-'
# Row 570 | Parsed: start=2022, end=2025, ongoing=True
# Row 571 | Raw '2022-'
# Row 571 | Parsed: start=2022, end=2025, ongoing=True
# Row 572 | Raw '2003-2005'
# Row 572 | Parsed: start=2003, end=2005, ongoing=False
# Row 573 | Raw '1993-2000'
# Row 573 | Parsed: start=1993, end=2000, ongoing=False
# Row 574 | Raw '1998-2007'
# Row 574 | Parsed: start=1998, end=2007, ongoing=False
# Row 575 | Raw '2022-'
# Row 575 | Parsed: start=2022, end=2025, ongoing=True
# Row 576 | Raw '1988-2018'
# Row 576 | Parsed: start=1988, end=2018, ongoing=False
# Row 577 | Raw '2004-2007'
# Row 577 | Parsed: start=2004, end=2007, ongoing=False
# Row 578 | Raw '2022'
# Row 578 | Parsed: start=2022, end=2022, ongoing=False
# Row 579 | Raw '2001-2022'
# Row 579 | Parsed: start=2001, end=2022, ongoing=False
# Row 580 | Raw '1990-'
# Row 580 | Parsed: start=1990, end=2025, ongoing=True
# Row 581 | Raw '2019-2022'
# Row 581 | Parsed: start=2019, end=2022, ongoing=False
# Row 582 | Raw '2021-2024'
# Row 582 | Parsed: start=2021, end=2024, ongoing=False
# Row 583 | Raw '2016-2018'
# Row 583 | Parsed: start=2016, end=2018, ongoing=False
# Row 584 | Raw '2019-2024'
# Row 584 | Parsed: start=2019, end=2024, ongoing=False
# Row 585 | Raw '2014-2021'
# Row 585 | Parsed: start=2014, end=2021, ongoing=False
# Row 586 | Raw '2007-2012'
# Row 586 | Parsed: start=2007, end=2012, ongoing=False
# Row 587 | Raw '2009-2015'
# Row 587 | Parsed: start=2009, end=2015, ongoing=False
# Row 588 | Raw '2005-2010'
# Row 588 | Parsed: start=2005, end=2010, ongoing=False
# Row 589 | Raw '2008-2013'
# Row 589 | Parsed: start=2008, end=2013, ongoing=False
# Row 590 | Raw '2015-2017'
# Row 590 | Parsed: start=2015, end=2017, ongoing=False
# Row 591 | Raw '2024-'
# Row 591 | Parsed: start=2024, end=2025, ongoing=True
# Row 592 | Raw '2015-2019'
# Row 592 | Parsed: start=2015, end=2019, ongoing=False
# Row 593 | Raw '2011-2016'
# Row 593 | Parsed: start=2011, end=2016, ongoing=False
# Row 594 | Raw '2011-2025'
# Row 594 | Parsed: start=2011, end=2025, ongoing=False
# Row 595 | Raw '1998-2003'
# Row 595 | Parsed: start=1998, end=2003, ongoing=False
# Row 596 | Raw '2021-2024'
# Row 596 | Parsed: start=2021, end=2024, ongoing=False
# Row 597 | Raw '1995-1998'
# Row 597 | Parsed: start=1995, end=1998, ongoing=False
# Row 598 | Raw '2016-2022'
# Row 598 | Parsed: start=2016, end=2022, ongoing=False
# Row 599 | Raw '2020-'
# Row 599 | Parsed: start=2020, end=2025, ongoing=True
# Row 600 | Raw '2018-2021'
# Row 600 | Parsed: start=2018, end=2021, ongoing=False
# Row 601 | Raw '2022-2023'
# Row 601 | Parsed: start=2022, end=2023, ongoing=False
# Row 602 | Raw '2001'
# Row 602 | Parsed: start=2001, end=2001, ongoing=False
# Row 603 | Raw '2006-2011'
# Row 603 | Parsed: start=2006, end=2011, ongoing=False
# Row 604 | Raw '2013-2015'
# Row 604 | Parsed: start=2013, end=2015, ongoing=False
# Row 605 | Raw '2004-2007'
# Row 605 | Parsed: start=2004, end=2007, ongoing=False
# Row 606 | Raw '2011-2014'
# Row 606 | Parsed: start=2011, end=2014, ongoing=False
# Row 607 | Raw '2003-2004'
# Row 607 | Parsed: start=2003, end=2004, ongoing=False
# Row 608 | Raw '2021'
# Row 608 | Parsed: start=2021, end=2021, ongoing=False
# Row 609 | Raw '1996-2003'
# Row 609 | Parsed: start=1996, end=2003, ongoing=False
# Row 610 | Raw '2004-2006'
# Row 610 | Parsed: start=2004, end=2006, ongoing=False
# Row 611 | Raw '1971-1978'
# Row 611 | Parsed: start=1971, end=1978, ongoing=False
# Row 612 | Raw '2006-2011'
# ...
# Row 5950 | Raw '2007-2008'
# Row 5950 | Parsed: start=2007, end=2008, ongoing=False
# Row 5951 | Raw '2013-2014'
# Row 5951 | Parsed: start=2013, end=2014, ongoing=False
# Row 5952 | Raw '2007-2011'
# Row 5952 | Parsed: start=2007, end=2011, ongoing=False
# Row 5953 | Raw '2024'
# Row 5953 | Parsed: start=2024, end=2024, ongoing=False
# Row 5954 | Raw '2018-2023'
# Row 5954 | Parsed: start=2018, end=2023, ongoing=False
# Row 5955 | Raw '2011'
# Row 5955 | Parsed: start=2011, end=2011, ongoing=False
# Row 5956 | Raw '2006-2011'
# Row 5956 | Parsed: start=2006, end=2011, ongoing=False
# Row 5957 | Raw '1978-1981'
# Row 5957 | Parsed: start=1978, end=1981, ongoing=False
# Row 5958 | Raw '2021-2022'
# Row 5958 | Parsed: start=2021, end=2022, ongoing=False
# Row 5959 | Raw '1990-1991'
# Row 5959 | Parsed: start=1990, end=1991, ongoing=False
# Row 5960 | Raw '2020'
# Row 5960 | Parsed: start=2020, end=2020, ongoing=False
# Row 5961 | Raw '2018-2019'
# Row 5961 | Parsed: start=2018, end=2019, ongoing=False
# Row 5962 | Raw '2009-2013'
# Row 5962 | Parsed: start=2009, end=2013, ongoing=False
# Row 5963 | Raw '2009-2020'
# Row 5963 | Parsed: start=2009, end=2020, ongoing=False
# Row 5964 | Raw '2017-'
# Row 5964 | Parsed: start=2017, end=2025, ongoing=True
# Row 5965 | Raw '1982-1989'
# Row 5965 | Parsed: start=1982, end=1989, ongoing=False
# Row 5966 | Raw '2016-2019'
# Row 5966 | Parsed: start=2016, end=2019, ongoing=False
# Row 5967 | Raw '2020'
# Row 5967 | Parsed: start=2020, end=2020, ongoing=False
# Row 5968 | Raw '2020-'
# Row 5968 | Parsed: start=2020, end=2025, ongoing=True
# Row 5969 | Raw '2021-'
# Row 5969 | Parsed: start=2021, end=2025, ongoing=True
# Row 5970 | Raw '2018-2019'
# Row 5970 | Parsed: start=2018, end=2019, ongoing=False
# Row 5971 | Raw '2002-2004'
# Row 5971 | Parsed: start=2002, end=2004, ongoing=False
# Row 5972 | Raw '2023-'
# Row 5972 | Parsed: start=2023, end=2025, ongoing=True
# Row 5973 | Raw '2016-2017'
# Row 5973 | Parsed: start=2016, end=2017, ongoing=False
# Row 5974 | Raw '1992-1995'
# Row 5974 | Parsed: start=1992, end=1995, ongoing=False
# Row 5975 | Raw '2023-'
# Row 5975 | Parsed: start=2023, end=2025, ongoing=True
# Row 5976 | Raw '1969-1971'
# Row 5976 | Parsed: start=1969, end=1971, ongoing=False
# Row 5977 | Raw '2011-2025'
# Row 5977 | Parsed: start=2011, end=2025, ongoing=False
# Row 5978 | Raw '2016-2018'
# Row 5978 | Parsed: start=2016, end=2018, ongoing=False
# Row 5979 | Raw '2017'
# Row 5979 | Parsed: start=2017, end=2017, ongoing=False
# Row 5980 | Raw '2015-2016'
# Row 5980 | Parsed: start=2015, end=2016, ongoing=False
# Row 5981 | Raw '2006-2012'
# Row 5981 | Parsed: start=2006, end=2012, ongoing=False
# Row 5982 | Raw '1996-1999'
# Row 5982 | Parsed: start=1996, end=1999, ongoing=False
# Row 5983 | Raw '2004-'
# Row 5983 | Parsed: start=2004, end=2025, ongoing=True
# Row 5984 | Raw '2009-2010'
# Row 5984 | Parsed: start=2009, end=2010, ongoing=False
# Row 5985 | Raw '2013-2014'
# Row 5985 | Parsed: start=2013, end=2014, ongoing=False
# Row 5986 | Raw '2007'
# Row 5986 | Parsed: start=2007, end=2007, ongoing=False
# Row 5987 | Raw '1995-1998'
# Row 5987 | Parsed: start=1995, end=1998, ongoing=False
# Row 5988 | Raw '1985-1986'
# Row 5988 | Parsed: start=1985, end=1986, ongoing=False
# Row 5989 | Raw '2019-2020'
# Row 5989 | Parsed: start=2019, end=2020, ongoing=False
# Row 5990 | Raw '2014-2016'
# Row 5990 | Parsed: start=2014, end=2016, ongoing=False
# Row 5991 | Raw '2024-'
# Row 5991 | Parsed: start=2024, end=2025, ongoing=True
# Row 5992 | Raw '2008-2011'
# Row 5992 | Parsed: start=2008, end=2011, ongoing=False
# Row 5993 | Raw '1955-1963'
# Row 5993 | Parsed: start=1955, end=1963, ongoing=False
# Row 5994 | Raw '2021-2022'
# Row 5994 | Parsed: start=2021, end=2022, ongoing=False
# Row 5995 | Raw '2024'
# Row 5995 | Parsed: start=2024, end=2024, ongoing=False
# Row 5996 | Raw '2020'
# Row 5996 | Parsed: start=2020, end=2020, ongoing=False
# Row 5997 | Raw '2021'
# Row 5997 | Parsed: start=2021, end=2021, ongoing=False
# Row 5998 | Raw '1984-1988'
# Row 5998 | Parsed: start=1984, end=1988, ongoing=False
# Row 5999 | Raw '2022'
# Row 5999 | Parsed: start=2022, end=2022, ongoing=False
# Row 6000 | Raw '1964-1967'
# Row 6000 | Parsed: start=1964, end=1967, ongoing=False
# Row 6001 | Raw '2019'
# Row 6001 | Parsed: start=2019, end=2019, ongoing=False
# Row 6002 | Raw '2018-'
# Row 6002 | Parsed: start=2018, end=2025, ongoing=True
# Row 6003 | Raw '2000-2001'
# Row 6003 | Parsed: start=2000, end=2001, ongoing=False
# Row 6004 | Raw '2013-2024'
# Row 6004 | Parsed: start=2013, end=2024, ongoing=False
# Row 6005 | Raw '2017-2022'
# Row 6005 | Parsed: start=2017, end=2022, ongoing=False
# Row 6006 | Raw '2019-2020'
# Row 6006 | Parsed: start=2019, end=2020, ongoing=False
# Row 6007 | Raw '2022-'
# Row 6007 | Parsed: start=2022, end=2025, ongoing=True
# Row 6008 | Raw '2023-'
# Row 6008 | Parsed: start=2023, end=2025, ongoing=True
# Row 6009 | Raw '1975-'
# Row 6009 | Parsed: start=1975, end=2025, ongoing=True
# Row 6010 | Raw '2022'
# Row 6010 | Parsed: start=2022, end=2022, ongoing=False
# Row 6011 | Raw '2001-'
# Row 6011 | Parsed: start=2001, end=2025, ongoing=True
# Row 6012 | Raw '1983-2010'
# Row 6012 | Parsed: start=1983, end=2010, ongoing=False
# Row 6013 | Raw '1977-1979'
# Row 6013 | Parsed: start=1977, end=1979, ongoing=False
# Row 6014 | Raw '1987-'
# Row 6014 | Parsed: start=1987, end=2025, ongoing=True
# Row 6015 | Raw '2016-'
# Row 6015 | Parsed: start=2016, end=2025, ongoing=True
# Row 6016 | Raw '2001-2002'
# Row 6016 | Parsed: start=2001, end=2002, ongoing=False
# Row 6017 | Raw '2016'
# Row 6017 | Parsed: start=2016, end=2016, ongoing=False
# Row 6018 | Raw '2024-'
# Row 6018 | Parsed: start=2024, end=2025, ongoing=True
# Row 6019 | Raw '2018-2024'
# Row 6019 | Parsed: start=2018, end=2024, ongoing=False
# Row 6020 | Raw '2017-2021'
# Row 6020 | Parsed: start=2017, end=2021, ongoing=False
# Row 6021 | Raw '2007-2024'
# Row 6021 | Parsed: start=2007, end=2024, ongoing=False
# Row 6022 | Raw '2013'
# Row 6022 | Parsed: start=2013, end=2013, ongoing=False
# Row 6023 | Raw '2022-'
# Row 6023 | Parsed: start=2022, end=2025, ongoing=True
# Row 6024 | Raw '2003-2021'
# Row 6024 | Parsed: start=2003, end=2021, ongoing=False
# Row 6025 | Raw '2011-2012'
# Row 6025 | Parsed: start=2011, end=2012, ongoing=False
# Row 6026 | Raw '2020-'
# Row 6026 | Parsed: start=2020, end=2025, ongoing=True
# Row 6027 | Raw '2019-'
# Row 6027 | Parsed: start=2019, end=2025, ongoing=True
# Row 6028 | Raw '2023'
# Row 6028 | Parsed: start=2023, end=2023, ongoing=False
# Row 6029 | Raw '2024'
# Row 6029 | Parsed: start=2024, end=2024, ongoing=False
# Row 6030 | Raw '2019-'
# Row 6030 | Parsed: start=2019, end=2025, ongoing=True
# Row 6031 | Raw '2022-2024'
# Row 6031 | Parsed: start=2022, end=2024, ongoing=False
# Row 6032 | Raw '2021-2022'
# Row 6032 | Parsed: start=2021, end=2022, ongoing=False
# Row 6033 | Raw '1988-1990'
# Row 6033 | Parsed: start=1988, end=1990, ongoing=False
# Row 6034 | Raw '2017'
# Row 6034 | Parsed: start=2017, end=2017, ongoing=False
# Row 6035 | Raw '2023'
# Row 6035 | Parsed: start=2023, end=2023, ongoing=False
# Row 6036 | Raw '2020'
# Row 6036 | Parsed: start=2020, end=2020, ongoing=False
# Row 6037 | Raw '2019-2024'
# Row 6037 | Parsed: start=2019, end=2024, ongoing=False
# Row 6038 | Raw '2020'
# Row 6038 | Parsed: start=2020, end=2020, ongoing=False
# Row 6039 | Raw '2008'
# Row 6039 | Parsed: start=2008, end=2008, ongoing=False
# Row 6040 | Raw '2019-'
# Row 6040 | Parsed: start=2019, end=2025, ongoing=True
# Row 6041 | Raw '2022'
# Row 6041 | Parsed: start=2022, end=2022, ongoing=False
# Row 6042 | Raw '2023'
# Row 6042 | Parsed: start=2023, end=2023, ongoing=False
# Row 6043 | Raw '2017-'
# Row 6043 | Parsed: start=2017, end=2025, ongoing=True
# Row 6044 | Raw '2023'
# Row 6044 | Parsed: start=2023, end=2023, ongoing=False
# Row 6045 | Raw '1983-1985'
# Row 6045 | Parsed: start=1983, end=1985, ongoing=False
# Row 6046 | Raw '2011-'
# Row 6046 | Parsed: start=2011, end=2025, ongoing=True
# Row 6047 | Raw '2022'
# Row 6047 | Parsed: start=2022, end=2022, ongoing=False
# Row 6048 | Raw '2005-2010'
# Row 6048 | Parsed: start=2005, end=2010, ongoing=False
# Row 6049 | Raw '2020'
# Row 6049 | Parsed: start=2020, end=2020, ongoing=False
# Row 6050 | Raw '2008-2024'
# Row 6050 | Parsed: start=2008, end=2024, ongoing=False
# Row 6051 | Raw '1998-2001'
# Row 6051 | Parsed: start=1998, end=2001, ongoing=False
# Row 6052 | Raw '2017'
# Row 6052 | Parsed: start=2017, end=2017, ongoing=False
# Row 6053 | Raw '2012-2016'
# Row 6053 | Parsed: start=2012, end=2016, ongoing=False
# Row 6054 | Raw '2021-2023'
# Row 6054 | Parsed: start=2021, end=2023, ongoing=False
# Row 6055 | Raw '1993-1995'
# Row 6055 | Parsed: start=1993, end=1995, ongoing=False
# Row 6056 | Raw '2020'
# Row 6056 | Parsed: start=2020, end=2020, ongoing=False
# Row 6057 | Raw '2008'
# Row 6057 | Parsed: start=2008, end=2008, ongoing=False
# Row 6058 | Raw '2024'
# Row 6058 | Parsed: start=2024, end=2024, ongoing=False
# Row 6059 | Raw '1966-1968'
# Row 6059 | Parsed: start=1966, end=1968, ongoing=False
# Row 6060 | Raw '2008-2018'
# Row 6060 | Parsed: start=2008, end=2018, ongoing=False
# Row 6061 | Raw '1972-1973'
# Row 6061 | Parsed: start=1972, end=1973, ongoing=False
# Row 6062 | Raw '2021-2024'
# Row 6062 | Parsed: start=2021, end=2024, ongoing=False
# Row 6063 | Raw '1989'
# Row 6063 | Parsed: start=1989, end=1989, ongoing=False
# Row 6064 | Raw '2021'
# Row 6064 | Parsed: start=2021, end=2021, ongoing=False
# Row 6065 | Raw '2020-'
# Row 6065 | Parsed: start=2020, end=2025, ongoing=True
# Row 6066 | Raw '1990-1994'
# Row 6066 | Parsed: start=1990, end=1994, ongoing=False
# Row 6067 | Raw '2021-2022'
# Row 6067 | Parsed: start=2021, end=2022, ongoing=False
# Row 6068 | Raw '2001'
# Row 6068 | Parsed: start=2001, end=2001, ongoing=False
# Row 6069 | Raw '2001-2002'
# Row 6069 | Parsed: start=2001, end=2002, ongoing=False
# Row 6070 | Raw '2019-'
# Row 6070 | Parsed: start=2019, end=2025, ongoing=True
# Row 6071 | Raw '2018'
# Row 6071 | Parsed: start=2018, end=2018, ongoing=False
# Row 6072 | Raw '2022-2023'
# Row 6072 | Parsed: start=2022, end=2023, ongoing=False
# Row 6073 | Raw '1986-1991'
# Row 6073 | Parsed: start=1986, end=1991, ongoing=False
# Row 6074 | Raw '2005-2006'
# Row 6074 | Parsed: start=2005, end=2006, ongoing=False
# Row 6075 | Raw '2017-2018'
# Row 6075 | Parsed: start=2017, end=2018, ongoing=False
# Row 6076 | Raw '2019-'
# Row 6076 | Parsed: start=2019, end=2025, ongoing=True
# Row 6077 | Raw '1990-1993'
# Row 6077 | Parsed: start=1990, end=1993, ongoing=False
# Row 6078 | Raw '2017'
# Row 6078 | Parsed: start=2017, end=2017, ongoing=False
# Row 6079 | Raw '2005'
# Row 6079 | Parsed: start=2005, end=2005, ongoing=False
# Row 6080 | Raw '2018'
# Row 6080 | Parsed: start=2018, end=2018, ongoing=False
# Row 6081 | Raw '2022-'
# Row 6081 | Parsed: start=2022, end=2025, ongoing=True
# Row 6082 | Raw '2017-2019'
# Row 6082 | Parsed: start=2017, end=2019, ongoing=False
# Row 6083 | Raw '2013-'
# Row 6083 | Parsed: start=2013, end=2025, ongoing=True
# Row 6084 | Raw '2014-'
# Row 6084 | Parsed: start=2014, end=2025, ongoing=True
# Row 6085 | Raw '1996-1999'
# Row 6085 | Parsed: start=1996, end=1999, ongoing=False
# Row 6086 | Raw '2006-2009'
# Row 6086 | Parsed: start=2006, end=2009, ongoing=False
# Row 6087 | Raw '2018-2019'
# Row 6087 | Parsed: start=2018, end=2019, ongoing=False
# Row 6088 | Raw '2023-'
# Row 6088 | Parsed: start=2023, end=2025, ongoing=True
# Row 6089 | Raw '2007-2008'
# Row 6089 | Parsed: start=2007, end=2008, ongoing=False
# Row 6090 | Raw '2019-'
# Row 6090 | Parsed: start=2019, end=2025, ongoing=True
# Row 6091 | Raw '2008-2011'
# Row 6091 | Parsed: start=2008, end=2011, ongoing=False
# Row 6092 | Raw '2007-2009'
# Row 6092 | Parsed: start=2007, end=2009, ongoing=False
# Row 6093 | Raw '2024-'
# Row 6093 | Parsed: start=2024, end=2025, ongoing=True
# Row 6094 | Raw '2023-2024'
# Row 6094 | Parsed: start=2023, end=2024, ongoing=False
# Row 6095 | Raw '2021-'
# Row 6095 | Parsed: start=2021, end=2025, ongoing=True
# Row 6096 | Raw '2015-'
# Row 6096 | Parsed: start=2015, end=2025, ongoing=True
# Row 6097 | Raw '2025-'
# Row 6097 | Parsed: start=2025, end=2025, ongoing=True
# Row 6098 | Raw '1997-'
# Row 6098 | Parsed: start=1997, end=2025, ongoing=True
# Row 6099 | Raw '2022-'
# Row 6099 | Parsed: start=2022, end=2025, ongoing=True
# Row 6100 | Raw '1997-1998'
# Row 6100 | Parsed: start=1997, end=1998, ongoing=False
# Row 6101 | Raw '2011-2014'
# Row 6101 | Parsed: start=2011, end=2014, ongoing=False
# Row 6102 | Raw '2005-2006'
# Row 6102 | Parsed: start=2005, end=2006, ongoing=False
# Row 6103 | Raw '2016-2023'
# Row 6103 | Parsed: start=2016, end=2023, ongoing=False
# Row 6104 | Raw '2010-2017'
# Row 6104 | Parsed: start=2010, end=2017, ongoing=False
# Row 6105 | Raw '2001-2002'
# Row 6105 | Parsed: start=2001, end=2002, ongoing=False
# Row 6106 | Raw '2023'
# Row 6106 | Parsed: start=2023, end=2023, ongoing=False
# Row 6107 | Raw '2021-'
# Row 6107 | Parsed: start=2021, end=2025, ongoing=True
# Row 6108 | Raw '1994-1999'
# Row 6108 | Parsed: start=1994, end=1999, ongoing=False
# Row 6109 | Raw '2018-'
# Row 6109 | Parsed: start=2018, end=2025, ongoing=True
# Row 6110 | Raw '2007-'
# Row 6110 | Parsed: start=2007, end=2025, ongoing=True
# Row 6111 | Raw '1991-1993'
# Row 6111 | Parsed: start=1991, end=1993, ongoing=False
# Row 6112 | Raw '2010-'
# Row 6112 | Parsed: start=2010, end=2025, ongoing=True
# Row 6113 | Raw '2003-2006'
# Row 6113 | Parsed: start=2003, end=2006, ongoing=False
# Row 6114 | Raw '1960-1964'
# Row 6114 | Parsed: start=1960, end=1964, ongoing=False
# Row 6115 | Raw '2024-2025'
# Row 6115 | Parsed: start=2024, end=2025, ongoing=False
# Row 6116 | Raw '1991-1994'
# Row 6116 | Parsed: start=1991, end=1994, ongoing=False
# Row 6117 | Raw '2016'
# Row 6117 | Parsed: start=2016, end=2016, ongoing=False
# Row 6118 | Raw '2019-'
# Row 6118 | Parsed: start=2019, end=2025, ongoing=True
# Row 6119 | Raw '2001-2002'
# Row 6119 | Parsed: start=2001, end=2002, ongoing=False
# Row 6120 | Raw '1992-1997'
# Row 6120 | Parsed: start=1992, end=1997, ongoing=False
# Row 6121 | Raw '2007-'
# Row 6121 | Parsed: start=2007, end=2025, ongoing=True
# Row 6122 | Raw '2011-2012'
# Row 6122 | Parsed: start=2011, end=2012, ongoing=False
# Row 6123 | Raw '2023-'
# Row 6123 | Parsed: start=2023, end=2025, ongoing=True
# Row 6124 | Raw '1996-2001'
# Row 6124 | Parsed: start=1996, end=2001, ongoing=False
# Row 6125 | Raw '2020-2022'
# Row 6125 | Parsed: start=2020, end=2022, ongoing=False
# Row 6126 | Raw '2020-2022'
# Row 6126 | Parsed: start=2020, end=2022, ongoing=False
# Row 6127 | Raw '1977-1980'
# Row 6127 | Parsed: start=1977, end=1980, ongoing=False
# Row 6128 | Raw '2016-2017'
# Row 6128 | Parsed: start=2016, end=2017, ongoing=False
# Row 6129 | Raw '1976-1982'
# Row 6129 | Parsed: start=1976, end=1982, ongoing=False
# Row 6130 | Raw '2008-2021'
# Row 6130 | Parsed: start=2008, end=2021, ongoing=False
# Row 6131 | Raw '2021'
# Row 6131 | Parsed: start=2021, end=2021, ongoing=False
# Row 6132 | Raw '2021'
# Row 6132 | Parsed: start=2021, end=2021, ongoing=False
# Row 6133 | Raw '1998-2000'
# Row 6133 | Parsed: start=1998, end=2000, ongoing=False
# Row 6134 | Raw '2011-'
# Row 6134 | Parsed: start=2011, end=2025, ongoing=True
# Row 6135 | Raw '2012-2013'
# Row 6135 | Parsed: start=2012, end=2013, ongoing=False
# Row 6136 | Raw '2007-2017'
# Row 6136 | Parsed: start=2007, end=2017, ongoing=False
# Row 6137 | Raw '1969-1970'
# Row 6137 | Parsed: start=1969, end=1970, ongoing=False
# Row 6138 | Raw '2020-'
# Row 6138 | Parsed: start=2020, end=2025, ongoing=True
# Row 6139 | Raw '2023-'
# Row 6139 | Parsed: start=2023, end=2025, ongoing=True
# Row 6140 | Raw '1995-1996'
# Row 6140 | Parsed: start=1995, end=1996, ongoing=False
# Row 6141 | Raw '1999-2000'
# Row 6141 | Parsed: start=1999, end=2000, ongoing=False
# Row 6142 | Raw '2011'
# Row 6142 | Parsed: start=2011, end=2011, ongoing=False
# Row 6143 | Raw '2018-'
# Row 6143 | Parsed: start=2018, end=2025, ongoing=True
# Row 6144 | Raw '1994-1997'
# Row 6144 | Parsed: start=1994, end=1997, ongoing=False
# Row 6145 | Raw '1981-1982'
# Row 6145 | Parsed: start=1981, end=1982, ongoing=False
# Row 6146 | Raw '2004-2005'
# Row 6146 | Parsed: start=2004, end=2005, ongoing=False
# Row 6147 | Raw '2007-2008'
# Row 6147 | Parsed: start=2007, end=2008, ongoing=False
# Row 6148 | Raw '2020-2021'
# Row 6148 | Parsed: start=2020, end=2021, ongoing=False
# Row 6149 | Raw '2011-2018'
# Row 6149 | Parsed: start=2011, end=2018, ongoing=False
#
# ✅ Processed DataFrame:

# %%
df_shows[df_shows['ongoing']]
# Out:
#       Rank                                 Series  Years Content Rating  \
# 9       10                               The Boys  2019-          TV-MA
# 13      14                         True Detective  2014-          TV-MA
# 14      15                           Black Mirror  2011-          TV-MA
# 16      17                         Rick and Morty  2013-          TV-MA
# 19      20                        The Mandalorian  2019-          TV-14
# ...    ...                                    ...    ...            ...
# 6123  6124                           Highway Love  2023-            NaN
# 6134  6135                        Finding Bigfoot  2011-          TV-PG
# 6138  6139         The American Barbecue Showdown  2020-           TV-G
# 6139  6140                Missing: Dead or Alive?  2023-          TV-MA
# 6143  6144  The Last Drive-In with Joe Bob Briggs  2018-      Not Rated
#
#       IMDb Rating Total Ratings start_year end_year  ongoing run_length
# 9             8.6        (760K)       2019     2025     True          6
# 13            8.9        (694K)       2014     2025     True         11
# 14            8.7        (673K)       2011     2025     True         14
# 16            9.1        (640K)       2013     2025     True         12
# 19            8.6        (617K)       2019     2025     True          6
# ...           ...           ...        ...      ...      ...        ...
# 6123          7.3        (2.1K)       2023     2025     True          2
# 6134          4.1        (2.1K)       2011     2025     True         14
# 6138          7.2        (2.1K)       2020     2025     True          5
# 6139          5.8        (2.1K)       2023     2025     True          2
# 6143          9.4        (2.1K)       2018     2025     True          7
#
# [1295 rows x 10 columns]

# %%
import re

def convert_shorthand(value):
    """
    Converts IMDb-style shorthand values into full integers:
      - "(1.2K)" -> 1200
      - "(3.5M)" -> 3500000
      - "(750)"   -> 750
    Also removes any non-numeric characters like parentheses.
    """
    if pd.isna(value):  # Handle NaN values safely
        return None
    
    value = str(value).strip("()")  # Remove parentheses

    if "K" in value:
        return int(float(value.replace("K", "")) * 1_000)
    elif "M" in value:
        return int(float(value.replace("M", "")) * 1_000_000)
    elif value.isdigit():  # If it's already a number
        return int(value)
    
    return None  # If something unexpected is found



# Apply function to column
df_shows["Total Ratings"] = df_shows["Total Ratings"].apply(convert_shorthand)

df_shows
# Out:
#       Rank                            Series      Years Content Rating  \
# 0        1                   Game of Thrones  2011-2019          TV-MA
# 1        2                      Breaking Bad  2008-2013          TV-MA
# 2        3                   Stranger Things  2016-2025          TV-14
# 3        4                           Friends  1994-2004          TV-14
# 4        5                  The Walking Dead  2010-2022          TV-MA
# ...    ...                               ...        ...            ...
# 6145  6146                        Spider-Man  1981-1982          TV-Y7
# 6146  6147                  Complete Savages  2004-2005          TV-PG
# 6147  6148  A Shot at Love with Tila Tequila  2007-2008            NaN
# 6148  6149                             Ariza  2020-2021            NaN
# 6149  6150                            Tanked  2011-2018            NaN
#
#       IMDb Rating  Total Ratings start_year end_year  ongoing run_length
# 0             9.2        2400000       2011     2019    False          8
# 1             9.5        2300000       2008     2013    False          5
# 2             8.7        1400000       2016     2025    False          9
# 3             8.9        1100000       1994     2004    False         10
# 4             8.1        1100000       2010     2022    False         12
# ...           ...            ...        ...      ...      ...        ...
# 6145          6.8           2100       1981     1982    False          1
# 6146          7.3           2100       2004     2005    False          1
# 6147          3.1           2100       2007     2008    False          1
# 6148          6.3           2100       2020     2021    False          1
# 6149          6.5           2000       2011     2018    False          7
#
# [6150 rows x 10 columns]

# %%
df_shows.dtypes
# Out:
# Rank               object
# Series             object
# Years              object
# Content Rating     object
# IMDb Rating       float64
# Total Ratings       int64
# start_year         object
# end_year           object
# ongoing              bool
# run_length         object
# dtype: object

# %%
df_shows['start_year'] = df_shows['start_year'].astype(int)
df_shows['end_year'] = df_shows['end_year'].astype(int)
df_shows['run_length'] = df_shows['run_length'].astype(int)

# %%
df_shows.dtypes
# Out:
# Rank               object
# Series             object
# Years              object
# Content Rating     object
# IMDb Rating       float64
# Total Ratings       int64
# start_year          int32
# end_year            int32
# ongoing              bool
# run_length          int32
# dtype: object

# %%
df_shows[(df_shows['Content Rating'].isnull())]
# Out:
#       Rank                            Series      Years Content Rating  \
# 66      67                         Aspirants      2021-            NaN
# 149    150                        The Heroes      2008-            NaN
# 372    373                    Sandeep Bhaiya       2023            NaN
# 387    388                 Sapne Vs Everyone      2023-            NaN
# 471    472               Indian Police Force      2024-            NaN
# ...    ...                               ...        ...            ...
# 6140  6141                       Nowhere Man  1995-1996            NaN
# 6142  6143                Üsküdar'a Giderken       2011            NaN
# 6147  6148  A Shot at Love with Tila Tequila  2007-2008            NaN
# 6148  6149                             Ariza  2020-2021            NaN
# 6149  6150                            Tanked  2011-2018            NaN
#
#       IMDb Rating  Total Ratings  start_year  end_year  ongoing  run_length
# 66            9.2         315000        2021      2025     True           4
# 149           8.4         170000        2008      2025     True          17
# 372           9.1          76000        2023      2023    False           0
# 387           9.3          73000        2023      2025     True           2
# 471           5.0          59000        2024      2025     True           1
# ...           ...            ...         ...       ...      ...         ...
# 6140          8.3           2100        1995      1996    False           1
# 6142          8.4           2100        2011      2011    False           0
# 6147          3.1           2100        2007      2008    False           1
# 6148          6.3           2100        2020      2021    False           1
# 6149          6.5           2000        2011      2018    False           7
#
# [1207 rows x 10 columns]

# %%
content_rating_mapping = {
    # Group similar "no rating" values together:
    "Unrated": "Not Rated",
    "Not Rated": "Not Rated",
    "Approved": "Not Rated",
    
    # "E" means "Everyone" -> Closest match in TV ratings is TV-G
    "E": "TV-G",

    # Convert nonstandard or movie-style ratings into TV ratings:
    "M": "TV-MA",         # Assume M (Mature) translates roughly to TV-MA for shows
    "MA-17": "TV-MA",      # Mature content becomes TV-MA
    "18+": "TV-MA",        # Adult-only content becomes TV-MA
    "16+": "TV-MA",        # 16+ content approximated as TV-MA
    "13+": "TV-14",        # 13+ content approximated as TV-14

    # Handling nonstandard TV ratings:
    # "TV-Y7-FV": "TV-Y7",   # Remove the "-FV" suffix; still TV-Y7

    # Convert movie-style ratings that might appear:
    "PG-13": "TV-14",      # No official TV-PG-13 exists; map PG-13 to TV-14
    "R": "TV-MA",         # R-rated content becomes TV-MA in a TV context
    "TV-13": "TV-14",      # Map TV-13 to TV-14 (there's no standard TV-13 rating)
    "PG": "TV-PG",         # Map PG to TV-PG
    "G": "TV-PG",
    # Standard TV ratings (pass-through)
    "TV-Y": "TV-Y",
    "TV-Y7": "TV-Y7",
    "TV-G": "TV-G",
    "TV-PG": "TV-PG",
    "TV-14": "TV-14",
    "TV-MA": "TV-MA"
}


# Step 2: Apply mapping to standardize ratings (without filling nulls)
df_shows["Content Rating"] = df_shows["Content Rating"].replace(content_rating_mapping)

# Step 3: Print unique values after cleaning (debugging)
df_shows['Content Rating'].value_counts()
# Out:
# Content Rating
# TV-14        1691
# TV-MA        1598
# TV-PG         892
# TV-Y7         251
# TV-G          245
# TV-Y          141
# Not Rated      84
# TV-Y7-FV       41
# Name: count, dtype: int64

# %%
df_shows
# Out:
#       Rank                            Series      Years Content Rating  \
# 0        1                   Game of Thrones  2011-2019          TV-MA
# 1        2                      Breaking Bad  2008-2013          TV-MA
# 2        3                   Stranger Things  2016-2025          TV-14
# 3        4                           Friends  1994-2004          TV-14
# 4        5                  The Walking Dead  2010-2022          TV-MA
# ...    ...                               ...        ...            ...
# 6145  6146                        Spider-Man  1981-1982          TV-Y7
# 6146  6147                  Complete Savages  2004-2005          TV-PG
# 6147  6148  A Shot at Love with Tila Tequila  2007-2008            NaN
# 6148  6149                             Ariza  2020-2021            NaN
# 6149  6150                            Tanked  2011-2018            NaN
#
#       IMDb Rating  Total Ratings  start_year  end_year  ongoing  run_length
# 0             9.2        2400000        2011      2019    False           8
# 1             9.5        2300000        2008      2013    False           5
# 2             8.7        1400000        2016      2025    False           9
# 3             8.9        1100000        1994      2004    False          10
# 4             8.1        1100000        2010      2022    False          12
# ...           ...            ...         ...       ...      ...         ...
# 6145          6.8           2100        1981      1982    False           1
# 6146          7.3           2100        2004      2005    False           1
# 6147          3.1           2100        2007      2008    False           1
# 6148          6.3           2100        2020      2021    False           1
# 6149          6.5           2000        2011      2018    False           7
#
# [6150 rows x 10 columns]

# %%
df_shows['Content Rating'] = df_shows['Content Rating'].fillna('Not Rated')

# %%
df_shows['Content Rating'].value_counts()
# Out:
# Content Rating
# TV-14        1691
# TV-MA        1598
# Not Rated    1291
# TV-PG         892
# TV-Y7         251
# TV-G          245
# TV-Y          141
# TV-Y7-FV       41
# Name: count, dtype: int64

# %%
df_shows.isnull().sum()
# Out:
# Rank              0
# Series            0
# Years             0
# Content Rating    0
# IMDb Rating       0
# Total Ratings     0
# start_year        0
# end_year          0
# ongoing           0
# run_length        0
# dtype: int64

# %%
df_shows.duplicated().sum()
# Out:
# 0

# %%
df_shows.drop(columns='Years', axis=1, inplace=True)
df_shows.head()
# Out:
#   Rank            Series Content Rating  IMDb Rating  Total Ratings  \
# 0    1   Game of Thrones          TV-MA          9.2        2400000
# 1    2      Breaking Bad          TV-MA          9.5        2300000
# 2    3   Stranger Things          TV-14          8.7        1400000
# 3    4           Friends          TV-14          8.9        1100000
# 4    5  The Walking Dead          TV-MA          8.1        1100000
#
#    start_year  end_year  ongoing  run_length
# 0        2011      2019    False           8
# 1        2008      2013    False           5
# 2        2016      2025    False           9
# 3        1994      2004    False          10
# 4        2010      2022    False          12

# %%
df_shows
# Out:
#       Rank                            Series Content Rating  IMDb Rating  \
# 0        1                   Game of Thrones          TV-MA          9.2
# 1        2                      Breaking Bad          TV-MA          9.5
# 2        3                   Stranger Things          TV-14          8.7
# 3        4                           Friends          TV-14          8.9
# 4        5                  The Walking Dead          TV-MA          8.1
# ...    ...                               ...            ...          ...
# 6145  6146                        Spider-Man          TV-Y7          6.8
# 6146  6147                  Complete Savages          TV-PG          7.3
# 6147  6148  A Shot at Love with Tila Tequila      Not Rated          3.1
# 6148  6149                             Ariza      Not Rated          6.3
# 6149  6150                            Tanked      Not Rated          6.5
#
#       Total Ratings  start_year  end_year  ongoing  run_length
# 0           2400000        2011      2019    False           8
# 1           2300000        2008      2013    False           5
# 2           1400000        2016      2025    False           9
# 3           1100000        1994      2004    False          10
# 4           1100000        2010      2022    False          12
# ...             ...         ...       ...      ...         ...
# 6145           2100        1981      1982    False           1
# 6146           2100        2004      2005    False           1
# 6147           2100        2007      2008    False           1
# 6148           2100        2020      2021    False           1
# 6149           2000        2011      2018    False           7
#
# [6150 rows x 9 columns]

# %% [markdown]
# ### df_movies

# %%
df_movies.duplicated().sum()
# Out:
# 0

# %%
df_movies.isnull().sum().sort_values(ascending=False)
# Out:
# Metascore          964
# Year               522
# Total Ratings      216
# Rating             216
# Parental Rating    162
# Duration            54
# Title                0
# dtype: int64

# %%
df_movies.columns
# Out:
# Index(['Title', 'Year', 'Metascore', 'Total Ratings', 'Rating', 'Duration',
#        'Parental Rating'],
#       dtype='object')

# %%
def split_title_and_rank(df, title_col='Title'):
    """
    Splits the specified title column into two new columns: 'Rank' and 'Movie'.
    
    Assumes that each title entry is in the format: "rank. MovieName"
    
    Parameters:
        df (pd.DataFrame): DataFrame containing the title column.
        title_col (str): Name of the column to split (default 'Title').
    
    Returns:
        pd.DataFrame: DataFrame with new 'Rank' and 'Movie' columns.
    """
    # Split the column into two parts using the first occurrence of '.'
    df[['Rank', 'Movie']] = df[title_col].str.split('.', n=1, expand=True)
    
    # Remove extra whitespace from the new columns
    df['Rank'] = df['Rank'].str.strip()
    df['Movie'] = df['Movie'].str.strip()
    
    return df


df_movies = split_title_and_rank(df_movies)

# %%
df_movies.rename(columns={
    'Year': 'Parental Rating', 
    'Duration': 'Year', 
    'Parental Rating': 'Duration'
}, inplace=True)

# %%
df_movies.drop(columns='Title', inplace=True)

# %%
df_movies.columns
# Out:
# Index(['Parental Rating', 'Metascore', 'Total Ratings', 'Rating', 'Year',
#        'Duration', 'Rank', 'Movie'],
#       dtype='object')

# %%
ordered_columns = ['Rank', 'Movie', 'Year', 'Duration', 'Parental Rating', 'Rating', 'Total Ratings', 'Metascore']
df_movies = df_movies[ordered_columns].copy()
df_movies.head()
# Out:
#   Rank                             Movie  Year Duration Parental Rating  \
# 0    1                         The Gorge  2025    2h 7m           PG-13
# 1    2                     The Brutalist  2024   3h 34m               R
# 2    3                        The Monkey  2025   1h 38m               R
# 3    4  Captain America: Brave New World  2025   1h 58m           PG-13
# 4    5                         Nosferatu  2024   2h 12m               R
#
#    Rating Total Ratings  Metascore
# 0     6.8         (76K)       57.0
# 1     7.6         (59K)       90.0
# 2     6.4         (16K)       61.0
# 3     6.0         (65K)       42.0
# 4     7.3        (171K)       78.0

# %%
df_movies["Total Ratings"] = df_movies["Total Ratings"].apply(convert_shorthand)

# %%
df_movies['Parental Rating'].value_counts()
# Out:
# Parental Rating
# R            2549
# PG-13        1454
# PG            803
# Not Rated     248
# Approved      132
# TV-MA         130
# G             128
# Unrated        64
# TV-14          45
# NC-17          28
# TV-PG          12
# GP              7
# X               6
# 18+             4
# TV-G            4
# M               4
# Passed          3
# 13+             2
# M/PG            2
# 16+             2
# TV-Y7           1
# Name: count, dtype: int64

# %%
movie_rating_mapping = {
    # Keep official MPAA movie ratings as they are
    "G": "G",                # General Audience
    "PG": "PG",              # Parental Guidance Suggested
    "PG-13": "PG-13",        # Parents Strongly Cautioned
    "R": "R",                # Restricted
    "NC-17": "NC-17",        # No One 17 and Under Admitted

    # Merge old/classic ratings into modern equivalents
    "Approved": "Not Rated", # Pre-MPAA rating; best mapped to "Not Rated"
    "Passed": "Not Rated",   # Used before MPAA existed; map to "Not Rated"
    "GP": "PG",              # "GP" was the old name for "PG"
    "M": "PG",               # The original "M" (1968) was replaced by "GP" (later PG)
    "M/PG": "PG",            # Transition between M and PG
    "X": "NC-17",            # "X" was replaced by "NC-17"

    # Handling TV ratings (not used for movies)
    "TV-MA": "R",            # TV-MA is the closest equivalent to R
    "TV-14": "PG-13",        # TV-14 aligns best with PG-13
    "TV-PG": "PG",           # TV-PG is closest to PG
    "TV-G": "G",             # TV-G is closest to G
    "TV-Y7": "G",            # TV-Y7 has no MPAA equivalent, but G is the safest

    # Handling platform-specific ratings (like Netflix)
    "18+": "NC-17",          # 18+ is effectively NC-17
    "16+": "R",              # 16+ is closer to R
    "13+": "PG-13",          # 13+ is closest to PG-13

    # Group "Not Rated" values together
    "Not Rated": "Not Rated",
    "Unrated": "Not Rated"
}
df_movies['Parental Rating'] = df_movies['Parental Rating'].replace(movie_rating_mapping)

# %%
df_movies['Parental Rating'] = df_movies['Parental Rating'].fillna("Not Rated")

# %%
df_movies['Parental Rating'].value_counts()
# Out:
# Parental Rating
# R            2681
# PG-13        1501
# Not Rated     969
# PG            828
# G             133
# NC-17          38
# Name: count, dtype: int64

# %%
df_movies.isnull().sum().sort_values(ascending = False)
# Out:
# Metascore          964
# Rating             216
# Total Ratings      216
# Duration           162
# Year                54
# Rank                 0
# Movie                0
# Parental Rating      0
# dtype: int64

# %%
df_movies[(df_movies['Total Ratings'].isnull()) | (df_movies['Rating'].isnull())]
# Out:
#       Rank                 Movie  Year Duration Parental Rating  Rating  \
# 15      16               Shrek 5  2026      NaN       Not Rated     NaN
# 24      25  Another Simple Favor  2025       2h       Not Rated     NaN
# 27      28            Snow White  2025   1h 49m              PG     NaN
# 41      42           The Odyssey  2026      NaN       Not Rated     NaN
# 50      51               Holland  2025   1h 48m               R     NaN
# ...    ...                   ...   ...      ...             ...     ...
# 6029  6030             Die Early   NaN      NaN       Not Rated     NaN
# 6047  6048           Day Drinker   NaN      NaN       Not Rated     NaN
# 6049  6050               Emperor   NaN      NaN       Not Rated     NaN
# 6100  6101       Lethal Weapon 5   NaN      NaN       Not Rated     NaN
# 6108  6109           War Machine   NaN      NaN       Not Rated     NaN
#
#       Total Ratings  Metascore
# 15              NaN        NaN
# 24              NaN        NaN
# 27              NaN        NaN
# 41              NaN        NaN
# 50              NaN        NaN
# ...             ...        ...
# 6029            NaN        NaN
# 6047            NaN        NaN
# 6049            NaN        NaN
# 6100            NaN        NaN
# 6108            NaN        NaN
#
# [216 rows x 8 columns]

# %%
df_movies["Total Ratings"].fillna(0, inplace=True)  # No reviews = 0 total ratings
df_movies["Rating"].fillna(0, inplace=True)  # No reviews = No IMDb score, so 0
# Out:
# C:\Users\manar\AppData\Local\Temp\ipykernel_25472\979146473.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_movies["Total Ratings"].fillna(0, inplace=True)  # No reviews = 0 total ratings
# C:\Users\manar\AppData\Local\Temp\ipykernel_25472\979146473.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_movies["Rating"].fillna(0, inplace=True)  # No reviews = No IMDb score, so 0

# %%
df_movies["Duration"].fillna("Unspecified", inplace=True)
# Out:
# C:\Users\manar\AppData\Local\Temp\ipykernel_25472\1258444623.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_movies["Duration"].fillna("Unspecified", inplace=True)

# %%
df_movies.dropna(subset=["Year"], inplace=True)
# Drop nulls in year since its only 0.88% of the data (54 rows) and years are a critical feature when building the models

# %%
df_movies.isnull().sum()
# Out:
# Rank                 0
# Movie                0
# Year                 0
# Duration             0
# Parental Rating      0
# Rating               0
# Total Ratings        0
# Metascore          910
# dtype: int64

# %%
# Step 1: Create a "Has Metascore" column BEFORE filling NaNs
# This column marks whether the original movie had a Metascore (1 = Has Metascore, 0 = Missing)
df_movies["Has Metascore"] = df_movies["Metascore"].isna().astype(int).replace({1: 0, 0: 1})

# Step 2: Fill missing Metascore values with the median
# Some clustering models do not handle NaN values well, so we replace missing Metascores 
# with the median to maintain a reasonable distribution without introducing artificial clusters.
median_metascore = df_movies["Metascore"].median()
df_movies["Metascore"].fillna(median_metascore, inplace=True)

# Step 3: Ensure Metascore is stored as an integer
# We convert Metascore to an integer type to keep the dataset consistent for analysis and modeling.
df_movies["Metascore"] = df_movies["Metascore"].astype(int)  

# Step 4: Verify the changes
print(df_movies["Has Metascore"].value_counts())  # Should show both 1s and 0s
print(df_movies.isna().sum())  # Should show 0 missing values for Metascore
# Out:
# Has Metascore
# 1    5186
# 0     910
# Name: count, dtype: int64
# Rank               0
# Movie              0
# Year               0
# Duration           0
# Parental Rating    0
# Rating             0
# Total Ratings      0
# Metascore          0
# Has Metascore      0
# dtype: int64
# C:\Users\manar\AppData\Local\Temp\ipykernel_25472\2467022362.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_movies["Metascore"].fillna(median_metascore, inplace=True)

# %%
df_movies[df_movies['Has Metascore'] == 0]
# Fill missing Metascore values with the median to prevent bias in the clustering model later on.
# Added a "Has Metascore" column to differentiate between real Metascore values and imputed ones,
# ensuring the model is not negatively impacted by missing data.
# Out:
#       Rank                 Movie  Year     Duration Parental Rating  Rating  \
# 13      14      My Fault: London  2025           2h       Not Rated     6.2
# 15      16               Shrek 5  2026  Unspecified       Not Rated     0.0
# 24      25  Another Simple Favor  2025           2h       Not Rated     0.0
# 27      28            Snow White  2025       1h 49m              PG     0.0
# 29      30              Ne Zha 2  2025       2h 23m       Not Rated     8.2
# ...    ...                   ...   ...          ...             ...     ...
# 6125  6126     The Cleaning Lady  2018       1h 30m       Not Rated     5.5
# 6128  6129               Bilitis  1977       1h 35m               R     5.3
# 6132  6133              Curtains  1983       1h 29m               R     5.6
# 6136  6137               Redline  2009       1h 42m       Not Rated     7.5
# 6149  6150       I Am Still Here  2017       1h 44m       Not Rated     6.9
#
#       Total Ratings  Metascore  Has Metascore
# 13           7000.0         60              0
# 15              0.0         60              0
# 24              0.0         60              0
# 27              0.0         60              0
# 29           7200.0         60              0
# ...             ...        ...            ...
# 6125         4400.0         60              0
# 6128         2600.0         60              0
# 6132         6200.0         60              0
# 6136        19000.0         60              0
# 6149          497.0         60              0
#
# [910 rows x 9 columns]

# %%
# go back to 6th dimention --> Completeness

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
# go back to 7th dimension Accuracy

# %% [markdown]
# # Dealing with outliers

# %% [markdown]
# ### Statistically:

# %%
# Outlier Detection Functions
#These functions will be used later to detect potential outliers in numeric columns.

def detect_outliers_iqr(df, col):
  
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[col] < lower_bound) | (df[col] > upper_bound)]

def detect_outliers_zscore(df, col, threshold=3):

    # Compute z-scores for non-null values
    z_scores = zscore(df[col].dropna())
    mask = np.abs(z_scores) > threshold
    # Map back the index to the original DataFrame
    outlier_indices = df[col].dropna().index[mask]
    return df.loc[outlier_indices]

# %%
# TV Shows DataFrame Outlier Analysis

# Select numeric columns for df_shows
numeric_cols_shows = df_shows.select_dtypes(include=[np.number]).columns.tolist()
print(numeric_cols_shows)

for col in numeric_cols_shows:
    print(f"\n--- TV Shows Column: {col} ---")
    
    # Detect outliers using IQR method
    outliers_iqr = detect_outliers_iqr(df_shows, col)
    print("Outliers (IQR method):")
    print(outliers_iqr[[col]])
    
    # Detect outliers using Z-score method
    outliers_z = detect_outliers_zscore(df_shows, col)
    print("Outliers (Z-score method):")
    print(outliers_z[[col]])
    
    # Visualize using Boxplot and Histogram
    plt.figure(figsize=(10, 4))
    # Boxplot
    plt.subplot(1, 2, 1)
    sns.boxplot(y=df_shows[col])
    plt.title(f"df_shows Boxplot: {col}")
    # Histogram with KDE
    plt.subplot(1, 2, 2)
    sns.histplot(df_shows[col], bins=30, kde=True)
    plt.title(f"df_shows Histogram: {col}")
    plt.tight_layout()
    plt.show()

# %%
# Movies DataFrame Outlier Analysis

# Select numeric columns for df_movies
numeric_cols_movies = df_movies.select_dtypes(include=[np.number]).columns.tolist()
print(numeric_cols_movies)

for col in numeric_cols_movies:
    print(f"\n--- Movies Column: {col} ---")
    
    # Detect outliers using IQR method
    outliers_iqr = detect_outliers_iqr(df_movies, col)
    print("Outliers (IQR method):")
    print(outliers_iqr[[col]])
    
    # Detect outliers using Z-score method
    outliers_z = detect_outliers_zscore(df_movies, col)
    print("Outliers (Z-score method):")
    print(outliers_z[[col]])
    
    # Visualize using Boxplot and Histogram
    plt.figure(figsize=(10, 4))
    # Boxplot
    plt.subplot(1, 2, 1)
    sns.boxplot(y=df_movies[col])
    plt.title(f"df_movies Boxplot: {col}")
    # Histogram with KDE
    plt.subplot(1, 2, 2)
    sns.histplot(df_movies[col], bins=30, kde=True)
    plt.title(f"df_movies Histogram: {col}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 1. Univariate Graphical Analysis:
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or numerical.

# %% [markdown]
# #### I. Categorical Variables:
#
# we’ll use frequency table to understand distribution of each category
# - Bar Chart (Ordinal) - Orderd
# - Pie Chart (Nominal) - non Orderd

# %%
# For df_movies:
print("Frequency Distribution for 'Parental Rating' in df_movies:")
print(df_movies['Parental Rating'].value_counts())

# Bar Chart (Ordered)
plt.figure(figsize=(8, 4))
sns.countplot(x='Parental Rating', 
              data=df_movies, 
              order=df_movies['Parental Rating'].value_counts().index)
plt.title("Bar Chart of Parental Ratings (df_movies)")
plt.xlabel("Parental Rating")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# Pie Chart (Nominal)
plt.figure(figsize=(6, 6))
df_movies['Parental Rating'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Pie Chart of Parental Ratings (df_movies)")
plt.ylabel('')
plt.show()

# %%
# For df_shows: 
if 'Content Rating' in df_shows.columns:
    print("Frequency Distribution for 'Content Rating' in df_shows:")
    print(df_shows['Content Rating'].value_counts())
    
    # Bar Chart
    plt.figure(figsize=(8, 4))
    sns.countplot(x='Content Rating', 
                  data=df_shows, 
                  order=df_shows['Content Rating'].value_counts().index)
    plt.title("Bar Chart of Content Ratings (df_shows)")
    plt.xlabel("Content Rating")
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.show()
    
    # Pie Chart
    plt.figure(figsize=(6, 6))
    df_shows['Content Rating'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
    plt.title("Pie Chart of Content Ratings (df_shows)")
    plt.ylabel('')
    plt.show()

# %% [markdown]
# #### II. Numerical Variables:
#
# we need to understand the central tendency and spread of the variable (Descriptive Analysis) using:
#    - Box plot
#    - Histogram

# %%
# Movies 
# numerical columns for df_movies
numeric_cols_movies = df_movies.select_dtypes(include=[np.number]).columns.tolist()
print(numeric_cols_movies)

# Loop through each numeric column and create a boxplot and histogram
for col in numeric_cols_movies:
    plt.figure(figsize=(10, 4))
    
    # Boxplot 
    plt.subplot(1, 2, 1)
    sns.boxplot(y=df_movies[col])
    plt.title(f"df_movies Boxplot: {col}")
    
    # Histogram 
    plt.subplot(1, 2, 2)
    sns.histplot(df_movies[col], bins=30, kde=True)
    plt.title(f"df_movies Histogram: {col}")
    
    plt.tight_layout()
    plt.show()

# %%
# Shows
# Get all numeric columns in df_shows
numeric_cols_shows = df_shows.select_dtypes(include=[np.number]).columns.tolist()
print(numeric_cols_shows)

# Loop through each numeric column and create a boxplot and histogram
for col in numeric_cols_shows:
    plt.figure(figsize=(10, 4))
    
    # Boxplot
    plt.subplot(1, 2, 1)
    sns.boxplot(y=df_shows[col])
    plt.title(f"df_shows Boxplot: {col}")
    
    # Histogram 
    plt.subplot(1, 2, 2)
    sns.histplot(df_shows[col], bins=30, kde=True)
    plt.title(f"df_shows Histogram: {col}")
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 2. Univariate Non-Graphical analysis:
#
# - Where is the center of the data? (location) --> **Measures of central tendency**
# - How much does the data vary? (scale) --> **Measure of variability**
# - What is the shape of the data? (shape) --> **Measures of variation combined with an average (measure of center) gives a good picture of the distribution of the data.**

# %%
print(df_movies[numeric_cols_movies].describe())

# %%
print(df_movies['Parental Rating'].value_counts())

# %%
print(df_shows.describe())

# %%
print(df_shows['Content Rating'].value_counts())

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:
#
# Here, you look at the relationships between two or more variables. This can involve looking for correlations, patterns, and trends that suggest a relationship or an association.
#
# We can perform bi-variate analysis for any combination of categorical and numerical variables. The combination can be:
# | bi-variate variables   | Plot type |
# | ------------- | ------------- |
# | Categorical & Categorical| Stacked Bar Chart |
# | Categorical & numerical  | scatter plot, histogram, box plot|
# | numerical  & numerical  | Scatter plot, line chart|
#
#
# Multivariate Analysis:
# - Heat map
# - Bar Chart
# - Scatter Chart
# - Line Chart

# %% [markdown]
# #### Movies

# %%
# Correlation Matrix and Heatmap for Numerical Variables 
numeric_cols_movies = ['Rating', 'Total Ratings', 'Metascore']
corr_movies = df_movies[numeric_cols_movies].corr()
print("Correlation Matrix for Movies:")
print(corr_movies)

plt.figure(figsize=(6, 5))
sns.heatmap(corr_movies, annot=True, cmap="coolwarm")
plt.title("Movies: Correlation Matrix Heatmap")
plt.show()

# %%
# Scatter Plot (Numerical vs. Numerical)
# IMDb Rating vs. Total Ratings
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Rating', y='Total Ratings', data=df_movies)
plt.title("Movies: Scatter Plot – Rating vs. Total Ratings")
plt.xlabel("IMDb Rating")
plt.ylabel("Total Ratings")
plt.show()

# %%
# Box Plot (Categorical vs. Numerical)
# Boxplot of IMDb Rating grouped by Parental Rating
plt.figure(figsize=(8, 6))
sns.boxplot(x='Parental Rating', y='Rating', data=df_movies, order=df_movies['Parental Rating'].value_counts().index)
plt.title("Movies: IMDb Rating by Parental Rating")
plt.xlabel("Parental Rating")
plt.ylabel("IMDb Rating")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Shows

# %%
# Correlation Matrix and Heatmap for Numerical Variables
# 'IMDb Rating', 'Total Ratings', and 'run_length'
numeric_cols_shows = ['IMDb Rating', 'Total Ratings', 'run_length']
corr_shows = df_shows[numeric_cols_shows].corr()
print("Correlation Matrix for TV Shows:")
print(corr_shows)

plt.figure(figsize=(6, 5))
sns.heatmap(corr_shows, annot=True, cmap="coolwarm")
plt.title("TV Shows: Correlation Matrix Heatmap")
plt.show()

# %%
# Scatter Plot (Numerical vs. Numerical) 
# IMDb Rating vs. Total Ratings in TV shows
plt.figure(figsize=(8, 6))
sns.scatterplot(x='IMDb Rating', y='Total Ratings', data=df_shows)
plt.title("TV Shows: Scatter Plot – IMDb Rating vs. Total Ratings")
plt.xlabel("IMDb Rating")
plt.ylabel("Total Ratings")
plt.show()

# %%
# Box Plot (Categorical vs. Numerical)
# Boxplot of IMDb Rating grouped by Content Rating
if 'Content Rating' in df_shows.columns:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='Content Rating', y='IMDb Rating', data=df_shows, 
                order=df_shows['Content Rating'].value_counts().index)
    plt.title("TV Shows: IMDb Rating by Content Rating")
    plt.xlabel("Content Rating")
    plt.ylabel("IMDb Rating")
    plt.xticks(rotation=45)
    plt.show()

# %%
# Stacked Bar Chart (Categorical vs. Categorical) 
# Counts of TV shows by Content Rating and Ongoing status
# Convert the boolean 'ongoing' column to a string for plotting
df_shows['Ongoing Status'] = df_shows['ongoing'].map({True: 'Ongoing', False: 'Completed'})
plt.figure(figsize=(8, 6))
stacked_shows = df_shows.groupby(['Content Rating', 'Ongoing Status']).size().unstack(fill_value=0)
stacked_shows.plot(kind='bar', stacked=True)
plt.title("TV Shows: Stacked Bar Chart – Content Rating vs. Ongoing Status")
plt.xlabel("Content Rating")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# We could also use a correlation matrix to get more specific information about the relationship between these two variables.

# %% [markdown]
# # Our insights

# %% [markdown]
# #### Movies

# %%
numeric_cols_movies = ['Rating', 'Total Ratings', 'Metascore']

corr_movies = df_movies[numeric_cols_movies].corr()

plt.figure(figsize=(6, 5))
sns.heatmap(corr_movies, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Movies: Correlation Matrix Heatmap")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Rating', y='Total Ratings', data=df_movies, alpha=0.7)
plt.title("Movies: Scatter Plot – IMDb Rating vs. Total Ratings")
plt.xlabel("IMDb Rating")
plt.ylabel("Total Ratings")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Parental Rating', y='Rating', data=df_movies, 
            order=df_movies['Parental Rating'].value_counts().index)
plt.title("Movies: IMDb Rating by Parental Rating")
plt.xlabel("Parental Rating")
plt.ylabel("IMDb Rating")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Shows

# %%
numeric_cols_shows = ['IMDb Rating', 'Total Ratings', 'run_length']

corr_shows = df_shows[numeric_cols_shows].corr()

plt.figure(figsize=(6, 5))
sns.heatmap(corr_shows, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("TV Shows: Correlation Matrix Heatmap")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='IMDb Rating', y='Total Ratings', data=df_shows, alpha=0.7)
plt.title("TV Shows: Scatter Plot – IMDb Rating vs. Total Ratings")
plt.xlabel("IMDb Rating")
plt.ylabel("Total Ratings")
plt.show()

# %%
df_shows['Ongoing Status'] = df_shows['ongoing'].map({True: 'Ongoing', False: 'Completed'})

stacked_data = df_shows.groupby(['Content Rating', 'Ongoing Status']).size().unstack(fill_value=0)

plt.figure(figsize=(8, 6))
stacked_data.plot(kind='bar', stacked=True)
plt.title("TV Shows: Content Rating vs. Ongoing Status")
plt.xlabel("Content Rating")
plt.ylabel("Number of TV Shows")
plt.xticks(rotation=45)
plt.legend(title="Ongoing Status")
plt.show()
